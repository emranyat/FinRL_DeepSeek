# %% [markdown]
# <a href="https://colab.research.google.com/github/benstaf/FinRL_DeepSeek/blob/main/FinRL_DeepSeek_backtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FinRL-DeepSeek. Backtest

# %% [markdown]
# # Part 1. Install Packages

# %%
#!pip install git+https://github.com/emranyat/FinRL_DeepSeek.git
# !pip install git+https://github.com/emranyat/FinRL.git
# Out:
# Collecting git+https://github.com/emranyat/FinRL.git
#   Cloning https://github.com/emranyat/FinRL.git to c:\users\lenovo-pc\appdata\local\temp\pip-req-build-eq9wsuhj
#   Resolved https://github.com/emranyat/FinRL.git to commit f68607a12ac79e3f8e7d933dbacfb9d5957963b1
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\lenovo-pc\appdata\local\temp\pip-install-r4356tjq\elegantrl_f14a623456c647e7b94ddd3883451a3f
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 5e828af1503098f4da046c0f12432dbd4ef8bd97
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: alpaca-trade-api<4,>=3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from finrl==0.3.6) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from finrl==0.3.6) (3.1.60)
# Requirement already satisfied: exchange-calendars<5,>=4 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from finrl==0.3.6) (4.5.6)
# Requirement already satisfied: jqdatasdk<2,>=1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from finrl==0.3.6) (1.9.7)
# Requirement already satisfied: pyfolio<0.10,>=0.9 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from finrl==0.3.6) (0.9.2)
# Requirement already satisfied: pyportfolioopt<2,>=1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from finrl==0.3.6) (1.5.6)
# Requirement already satisfied: ray<3,>=2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.43.0)
# Requirement already satisfied: scikit-learn<2,>=1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from finrl==0.3.6) (1.6.1)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.6.0a2)
# Requirement already satisfied: stockstats<0.6,>=0.5 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from finrl==0.3.6) (0.5.4)
# Requirement already satisfied: wrds<4,>=3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from finrl==0.3.6) (3.3.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from finrl==0.3.6) (0.2.54)
# Requirement already satisfied: pandas>=0.18.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.2.3)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.4)
# Requirement already satisfied: requests<3,>2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.32.3)
# Requirement already satisfied: urllib3<2,>1.24 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.8.0)
# Requirement already satisfied: websockets<11,>=9.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (10.4)
# Requirement already satisfied: msgpack==1.0.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (3.11.13)
# Requirement already satisfied: PyYAML==6.0.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: packaging in c:\users\lenovo-pc\anaconda3\lib\site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (24.2)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (75.8.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (2025.1.31)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (3.4.8)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (3.2.0)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (1.18.3)
# Requirement already satisfied: pyluach in c:\users\lenovo-pc\anaconda3\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: toolz in c:\users\lenovo-pc\anaconda3\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: tzdata in c:\users\lenovo-pc\anaconda3\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2023.3)
# Requirement already satisfied: korean-lunar-calendar in c:\users\lenovo-pc\anaconda3\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.3.1)
# Requirement already satisfied: six in c:\users\lenovo-pc\anaconda3\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (2.0.37)
# Requirement already satisfied: pymysql>=0.7.6 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.1.1)
# Requirement already satisfied: thriftpy2<=0.4.20,>=0.3.9 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (0.4.20)
# Requirement already satisfied: ipython>=3.2.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (8.15.0)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\users\lenovo-pc\appdata\roaming\python\python39\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.7.2)
# Requirement already satisfied: pytz>=2014.10 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (2024.1)
# Requirement already satisfied: scipy>=0.14.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.13.1)
# Requirement already satisfied: seaborn>=0.7.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.13.2)
# Requirement already satisfied: empyrical>=0.5.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: cvxpy>=1.1.19 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.6.3)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (2.0.14)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (5.24.1)
# Requirement already satisfied: click>=7.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.7)
# Requirement already satisfied: filelock in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (3.13.1)
# Requirement already satisfied: jsonschema in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (4.23.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (4.25.6)
# Requirement already satisfied: aiosignal in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: frozenlist in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (1.5.0)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.6.2.2)
# Requirement already satisfied: pyarrow>=9.0.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (19.0.0)
# Requirement already satisfied: fsspec in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2024.12.0)
# Requirement already satisfied: aiohttp_cors in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: colorful in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.4.0)
# Requirement already satisfied: grpcio>=1.32.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.70.0)
# Requirement already satisfied: opencensus in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.11.4)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.10.3)
# Requirement already satisfied: prometheus_client>=0.7.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.21.0)
# Requirement already satisfied: smart_open in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (20.29.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (3.5.0)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.6.0)
# Requirement already satisfied: cloudpickle in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: opencv-python in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.10.0.84)
# Requirement already satisfied: pygame in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.13.0)
# Requirement already satisfied: psutil in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.66.5)
# Requirement already satisfied: rich in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.10.2)
# Requirement already satisfied: pillow in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (11.0.0)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from wrds<4,>=3->finrl==0.3.6) (2.9.10)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (3.10.0)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.12.3)
# Requirement already satisfied: th in c:\users\lenovo-pc\anaconda3\lib\site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.6) (0.4.1)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6) (4.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (2.5.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (0.3.0)
# Requirement already satisfied: importlib-metadata>=4.10.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ale-py>=0.9.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (6.8.0)
# Requirement already satisfied: typing-extensions in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ale-py>=0.9.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.5)
# Requirement already satisfied: colorama in c:\users\lenovo-pc\anaconda3\lib\site-packages (from click>=7.0->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.17.1)
# Requirement already satisfied: osqp>=0.6.2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.7.post3)
# Requirement already satisfied: clarabel>=0.5.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.7.post2)
# Requirement already satisfied: pandas-datareader>=0.2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.0.4)
# Requirement already satisfied: backcall in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: decorator in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.14.3)
# Requirement already satisfied: exceptiongroup in c:\users\lenovo-pc\anaconda3\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (6.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.6) (9.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl==0.3.6) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl==0.3.6) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.45.1)
# Requirement already satisfied: ply<4.0,>=3.4 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from thriftpy2<=0.4.20,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.11)
# Requirement already satisfied: networkx in c:\users\lenovo-pc\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.6.3)
# Requirement already satisfied: jinja2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (0.22.3)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.24.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: wrapt in c:\users\lenovo-pc\anaconda3\lib\site-packages (from smart_open->ray[default,tune]<3,>=2->finrl==0.3.6) (1.12.1)
# Requirement already satisfied: niltype<2.0,>=0.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.6) (1.0.2)
# Requirement already satisfied: pycparser in c:\users\lenovo-pc\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.69.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from importlib-metadata>=4.10.0->ale-py>=0.9.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.0)
# Requirement already satisfied: qdldl in c:\users\lenovo-pc\anaconda3\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7.post5)
# Requirement already satisfied: lxml in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.3.0)
# Requirement already satisfied: wcwidth in c:\users\lenovo-pc\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.2)
# Requirement already satisfied: executing in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\lenovo-pc\anaconda3\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.2)
#   Running command git clone --filter=blob:none --quiet https://github.com/emranyat/FinRL.git 'C:\Users\lenovo-pc\AppData\Local\Temp\pip-req-build-eq9wsuhj'
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git 'C:\Users\lenovo-pc\AppData\Local\Temp\pip-install-r4356tjq\elegantrl_f14a623456c647e7b94ddd3883451a3f'

# %%
# Download and install Spinning Up in Deep Reinforcement Learning

#!git clone https://github.com/benstaf/spinningup_pytorch.git
#%cd spinningup_pytorch
# !pip install -r requirements.txt
# !pip install -e .
# Out:
# Requirement already satisfied: alpaca_trade_api>=2.1.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: ccxt>=1.66.32 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (3.1.60)
# Requirement already satisfied: elegantrl in c:\users\lenovo-pc\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (0.3.10)
# Collecting exchange_calendars==3.6.3 (from -r requirements.txt (line 4))
#   Using cached exchange_calendars-3.6.3.tar.gz (152 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gputil (from -r requirements.txt (line 5))
#   Using cached GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: gymnasium in c:\users\lenovo-pc\anaconda3\lib\site-packages (from -r requirements.txt (line 6)) (1.1.1)
# Collecting importlib-metadata==4.13.0 (from -r requirements.txt (line 7))
#   Using cached importlib_metadata-4.13.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: jqdatasdk in c:\users\lenovo-pc\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (1.9.7)
# Collecting lz4 (from -r requirements.txt (line 9))
#   Using cached lz4-4.4.4-cp39-cp39-win_amd64.whl.metadata (3.9 kB)
# ERROR: Could not find a version that satisfies the requirement spinningup (from versions: none)
# ERROR: No matching distribution found for spinningup
# Obtaining file:///C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek
# ERROR: file:///C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !pip install selenium webdriver-manager alpaca-py datasets
# Out:
# Requirement already satisfied: selenium in c:\users\lenovo-pc\anaconda3\lib\site-packages (4.29.0)
# Requirement already satisfied: webdriver-manager in c:\users\lenovo-pc\anaconda3\lib\site-packages (4.0.2)
# Requirement already satisfied: alpaca-py in c:\users\lenovo-pc\anaconda3\lib\site-packages (0.39.0)
# Requirement already satisfied: datasets in c:\users\lenovo-pc\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.26.20)
# Requirement already satisfied: trio~=0.17 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: requests in c:\users\lenovo-pc\anaconda3\lib\site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\lenovo-pc\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in c:\users\lenovo-pc\anaconda3\lib\site-packages (from webdriver-manager) (24.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-py) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-py) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-py) (2.10.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-py) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from alpaca-py) (10.4)
# Requirement already satisfied: filelock in c:\users\lenovo-pc\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from datasets) (19.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\lenovo-pc\anaconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in c:\users\lenovo-pc\anaconda3\lib\site-packages (from datasets) (3.11.13)
# Requirement already satisfied: huggingface-hub>=0.24.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp->datasets) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pandas>=1.5.3->alpaca-py) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pandas>=1.5.3->alpaca-py) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pandas>=1.5.3->alpaca-py) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.7)
# Requirement already satisfied: colorama in c:\users\lenovo-pc\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: sortedcontainers in c:\users\lenovo-pc\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\lenovo-pc\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Requirement already satisfied: exceptiongroup in c:\users\lenovo-pc\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\lenovo-pc\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->alpaca-py) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\lenovo-pc\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# #Download environments: https://github.com/benstaf/FinRL_DeepSeek
# #And trading agents: https://huggingface.co/benstaf/Trading_agents

# %%
import random, torch, numpy as np
np.random.seed(42)
random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)

# %%
cd Documents/GitHub
# Out:
# C:\Users\lenovo-pc\Documents\GitHub

# %%
# !python FinRL_DeepSeek/bensatf_files/env_stocktrading_llm.py
# !python FinRL_DeepSeek/bensatf_files/env_stocktrading_llm_1.py
# !python FinRL_DeepSeek/bensatf_files/env_stocktrading_llm_01.py

# !python FinRL_DeepSeek/bensatf_files/env_stocktrading_llm_risk.py
# !python FinRL_DeepSeek/bensatf_files/env_stocktrading_llm_risk_1.py
# !python FinRL_DeepSeek/bensatf_files/env_stocktrading_llm_risk_01.py

# %%
# !python FinRL_DeepSeek/env_stocktrading.py

# !python FinRL_DeepSeek/env_trading_ppo_llm01_al01.py
# !python FinRL_DeepSeek/env_trading_ppo_llm01_al05.py
# !python FinRL_DeepSeek/env_trading_ppo_llm01_al025.py
# !python FinRL_DeepSeek/env_trading_ppo_llm01_al075.py
# !python FinRL_DeepSeek/env_trading_ppo_llm10_al075.py
# !python FinRL_DeepSeek/env_trading_ppo_ent.py
# !python FinRL_DeepSeek/env_trading_ppo_ent_llm01.py
# !python FinRL_DeepSeek/env_trading_ppo_ent_llm01_al075.py
# !python FinRL_DeepSeek/env_trading_ppo_Noconf.py


# !python FinRL_DeepSeek/env_trading_cppo_llm10.py
# !python FinRL_DeepSeek/env_trading_cppo_llm10_al025.py
# !python FinRL_DeepSeek/env_trading_cppo_llm01.py
# !python FinRL_DeepSeek/env_trading_cppo_Noconf.py
# !python FinRL_DeepSeek/env_trading_cppo_ent.py


# !python FinRL_DeepSeek/Files/env_stocktrading_ppo_trial.py
# !python FinRL_DeepSeek/Files/env_stocktrading_ppo_trial_v2.py
# !python FinRL_DeepSeek/Files/env_stocktrading_cppo_risk_trial.py
# !python FinRL_DeepSeek/Files/env_stocktrading_cppo_risk_trial_v2.py

# %%
# !cd Documents/GitHub/FinRL_DeepSeek && pwd
# Out:
# The system cannot find the path specified.

# %%
cd Documents//GitHub//FinRL_DeepSeek
# Out:
# C:\Users\lenovo-pc\Documents\GitHub\FinRL_DeepSeek

# %%
#!python C://Users//lenovo-pc//Documents//GitHub//FinRL_DeepSeek//env_stocktrading.py

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#from stable_baselines3 import A2C, DDPG, PPO, SAC, TD3

#from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS, TRAINED_MODEL_DIR
from env_stocktrading import StockTradingEnv

from env_trading_ppo_llm01_al01 import StockTradingEnv as StockTradingEnv_ppo_01_al01
from env_trading_ppo_llm01_al05 import StockTradingEnv as StockTradingEnv_ppo_01_al05
from env_trading_ppo_llm01_al025 import StockTradingEnv as StockTradingEnv_ppo_01_al025
from env_trading_ppo_llm01_al075 import StockTradingEnv as StockTradingEnv_ppo_01_al075
from env_trading_ppo_llm10_al075 import StockTradingEnv as StockTradingEnv_ppo_10_al075
from env_trading_ppo_ent import StockTradingEnv as StockTradingEnv_ppo_ent
from env_trading_ppo_Noconf import StockTradingEnv as StockTradingEnv_ppo_Noconf

from env_trading_cppo_llm10 import StockTradingEnv as StockTradingEnv_cppo_10
from env_trading_cppo_llm10_al025 import StockTradingEnv as StockTradingEnv_cppo_10_al025
from env_trading_cppo_llm10_al075 import StockTradingEnv as StockTradingEnv_cppo_10_al075
from env_trading_cppo_llm01 import StockTradingEnv as StockTradingEnv_cppo_01
from env_trading_cppo_Noconf import StockTradingEnv as StockTradingEnv_cppo_Noconf
from env_trading_cppo_ent import StockTradingEnv as StockTradingEnv_cppo_ent


from Files.env_stocktrading_ppo_trial import StockTradingEnv as StockTradingEnv_ppo
from Files.env_stocktrading_ppo_trial_v2 import StockTradingEnv as StockTradingEnv_ppo_v2
from Files.env_stocktrading_cppo_risk_trial import StockTradingEnv as StockTradingEnv_cppo
from Files.env_stocktrading_cppo_risk_trial_v2 import StockTradingEnv as StockTradingEnv_cppo_v2



# Import PPO-DeepSeek environments
#from bensatf_files.env_stocktrading_llm import StockTradingEnv as StockTradingEnv_llm
#from bensatf_files.env_stocktrading_llm_1 import StockTradingEnv as StockTradingEnv_llm_1
#from bensatf_files.env_stocktrading_llm_01 import StockTradingEnv as StockTradingEnv_llm_01

# Import CPPO-DeepSeek risk environments
#from bensatf_files.env_stocktrading_llm_risk import StockTradingEnv as StockTradingEnv_llm_risk
#from bensatf_files.env_stocktrading_llm_risk_1 import StockTradingEnv as StockTradingEnv_llm_risk_1
#from bensatf_files.env_stocktrading_llm_risk_01 import StockTradingEnv as StockTradingEnv_llm_risk_01

#from env_stocktrading_llm import StockTradingEnv as StockTradingEnv_llm

#from env_stocktrading_llm_risk import StockTradingEnv as StockTradingEnv_llm_risk


#from finrl.meta.env_stock_trading.env_stocktrading_llm import StockTradingEnv
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader


from datasets import load_dataset

# %matplotlib inline

# %% [markdown]
# # Part 2. Backtesting

# %%
# Read the dataset of trade data, emranyat
import pandas as pd
from datasets import load_dataset

dataset = pd.read_csv('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek//Files/trade_data_deepseek_risk_2019_2023_trial.csv')
trade = dataset.drop('Unnamed: 0',axis=1)
#trade = dataset.drop('Unnamed: 0.1',axis=1)

# Create a new index based on unique dates
unique_dates = trade['date'].unique()
date_to_idx = {date: idx for idx, date in enumerate(unique_dates)}

# Create new index based on the date mapping
trade['new_idx'] = trade['date'].map(date_to_idx)

# Set this as the index
trade = trade.set_index('new_idx')


#missing values with 0
trade['llm_sentiment'].fillna(0, inplace=True)
trade['llm_risk'].fillna(3, inplace=True)
trade['Confidence_Sen'].fillna(0, inplace=True)
trade['Confidence_Risk'].fillna(0, inplace=True)

trade_llm_risk=trade

# have trade_llm datafrane
trade_llm=trade_llm_risk.drop(['llm_risk','Confidence_Risk'],axis=1)

# have trade datafrane
trade=trade_llm.drop(['llm_sentiment','Confidence_Sen'],axis=1)
# Out:
# C:\Users\lenovo-pc\AppData\Local\Temp\ipykernel_18908\610827966.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   trade['llm_sentiment'].fillna(0, inplace=True)
# C:\Users\lenovo-pc\AppData\Local\Temp\ipykernel_18908\610827966.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   trade['llm_risk'].fillna(3, inplace=True)
# C:\Users\lenovo-pc\AppData\Local\Temp\ipykernel_18908\610827966.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   trade['Confidence_Sen'].fillna(0, inplace=True)
# C:\Users\lenovo-pc\AppData\Local\Temp\ipykernel_18908\610827966.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   trade['Confidence_Risk'].fillna(0, inplace=True)

# %%
stock_dimension = len(trade.tic.unique())
state_space = 1 + 2 * stock_dimension + len(INDICATORS) * stock_dimension #+ stock_dimension # +LLM sentiment
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 84, State Space: 841

# %%
stock_dimension = len(trade_llm.tic.unique())
state_space_llm = 1 + 2 * stock_dimension + (1+len(INDICATORS)) * stock_dimension #+ stock_dimension # +LLM sentiment
state_space_llm_v2 = 1 + 2 * stock_dimension + (2+len(INDICATORS)) * stock_dimension #+ stock_dimension # +LLM sentiment
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space_llm}")
# Out:
# Stock Dimension: 84, State Space: 925

# %%
stock_dimension = len(trade.tic.unique())
state_space_llm_risk = 1 + 2 * stock_dimension + (2+len(INDICATORS)) * stock_dimension #+ stock_dimension # +LLM sentiment + LLM risk
state_space_llm_risk_v2 = 1 + 2 * stock_dimension + (4+len(INDICATORS)) * stock_dimension #+ stock_dimension # +LLM sentiment + LLM risk
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space_llm_risk}")
# Out:
# Stock Dimension: 84, State Space: 1009

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %%
buy_cost_list_llm = sell_cost_list_llm = [0.001] * stock_dimension
num_stock_shares_llm = [0] * stock_dimension

env_kwargs_llm = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares_llm,
    "buy_cost_pct": buy_cost_list_llm,
    "sell_cost_pct": sell_cost_list_llm,
    "state_space": state_space_llm,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

env_kwargs_llm_v2 = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares_llm,
    "buy_cost_pct": buy_cost_list_llm,
    "sell_cost_pct": sell_cost_list_llm,
    "state_space": state_space_llm_v2,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs_llm_risk = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space_llm_risk,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

env_kwargs_llm_risk_v2 = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
"state_space": state_space_llm_risk_v2,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %%
# have gym ready, emranyat

e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
e_trade_llm_gym = StockTradingEnv_ppo(df = trade_llm, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm)
e_trade_llm_gym_v2 = StockTradingEnv_ppo_v2(df = trade_llm, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_llm_risk_gym = StockTradingEnv_cppo(df = trade_llm_risk, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_risk)
e_trade_llm_risk_gym_v2 = StockTradingEnv_cppo_v2(df = trade_llm_risk, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_risk_v2)

e_trade_ppo_gym_01_al01 = StockTradingEnv_ppo_01_al05(df = trade_llm, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_ppo_gym_01_al05 = StockTradingEnv_ppo_01_al05(df = trade_llm, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_ppo_gym_01_al025 = StockTradingEnv_ppo_01_al025(df = trade_llm, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_ppo_gym_01_al075 = StockTradingEnv_ppo_01_al075(df = trade_llm, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_ppo_gym_10_al075 = StockTradingEnv_ppo_10_al075(df = trade_llm, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_ppo_gym_ent = StockTradingEnv_ppo_ent(df = trade_llm, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_ppo_gym_Noconf = StockTradingEnv_ppo_Noconf(df = trade_llm, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)

e_trade_cppo_gym_10 = StockTradingEnv_cppo_10(df = trade_llm_risk, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_cppo_gym_01 = StockTradingEnv_cppo_01(df = trade_llm_risk, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_cppo_gym_10_al025 = StockTradingEnv_cppo_10_al025(df = trade_llm_risk, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_cppo_gym_10_al075 = StockTradingEnv_cppo_10_al075(df = trade_llm_risk, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_cppo_gym_Noconf = StockTradingEnv_cppo_Noconf(df = trade_llm_risk, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)
e_trade_cppo_gym_ent = StockTradingEnv_cppo_ent(df = trade_llm_risk, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs_llm_v2)

# %%
# observation space for the models of trial, emranyat

observation_space=e_trade_gym.observation_space
action_space=e_trade_gym.action_space
# PPO- deepseek
observation_space_llm=e_trade_llm_gym.observation_space
action_space_llm=e_trade_llm_gym.action_space
# PPO- deepseek v2
observation_space_llm_v2=e_trade_llm_gym_v2.observation_space
action_space_llm_v2=e_trade_llm_gym_v2.action_space
# CPPO- deepseek
observation_space_llm_risk=e_trade_llm_risk_gym.observation_space
action_space_llm_risk=e_trade_llm_risk_gym.action_space
# CPPO- deepseek v2
observation_space_llm_risk_v2=e_trade_llm_risk_gym_v2.observation_space
action_space_llm_risk_v2=e_trade_llm_risk_gym_v2.action_space

# %%
print("State shape:", observation_space_llm.shape)
# Out:
# State shape: (925,)

# %%
import numpy as np
import scipy.signal
from gymnasium.spaces import Box, Discrete

import torch
import torch.nn as nn
from torch.distributions.normal import Normal
from torch.distributions.categorical import Categorical


def combined_shape(length, shape=None):
    if shape is None:
        return (length,)
    return (length, shape) if np.isscalar(shape) else (length, *shape)


def mlp(sizes, activation, output_activation=nn.Identity):
    layers = []
    for j in range(len(sizes)-1):
        act = activation if j < len(sizes)-2 else output_activation
        layers += [nn.Linear(sizes[j], sizes[j+1]), act()]
    return nn.Sequential(*layers)


def count_vars(module):
    return sum([np.prod(p.shape) for p in module.parameters()])


def discount_cumsum(x, discount):
    """
    magic from rllab for computing discounted cumulative sums of vectors.

    input:
        vector x,
        [x0,
         x1,
         x2]

    output:
        [x0 + discount * x1 + discount^2 * x2,
         x1 + discount * x2,
         x2]
    """
    return scipy.signal.lfilter([1], [1, float(-discount)], x[::-1], axis=0)[::-1]


class Actor(nn.Module):

    def _distribution(self, obs):
        raise NotImplementedError

    def _log_prob_from_distribution(self, pi, act):
        raise NotImplementedError

    def forward(self, obs, act=None):
        # Produce action distributions for given observations, and
        # optionally compute the log likelihood of given actions under
        # those distributions.
        pi = self._distribution(obs)
        logp_a = None
        if act is not None:
            logp_a = self._log_prob_from_distribution(pi, act)
        return pi, logp_a


class MLPCategoricalActor(Actor):

    def __init__(self, obs_dim, act_dim, hidden_sizes, activation):
        super().__init__()
        self.logits_net = mlp([obs_dim] + list(hidden_sizes) + [act_dim], activation)

    def _distribution(self, obs):
        logits = self.logits_net(obs)
        return Categorical(logits=logits)

    def _log_prob_from_distribution(self, pi, act):
        return pi.log_prob(act)


class MLPGaussianActor(Actor):

    def __init__(self, obs_dim, act_dim, hidden_sizes, activation):
        super().__init__()
        log_std = -0.5 * np.ones(act_dim, dtype=np.float32)
        self.log_std = torch.nn.Parameter(torch.as_tensor(log_std))
        self.mu_net = mlp([obs_dim] + list(hidden_sizes) + [act_dim], activation)

    def _distribution(self, obs):
        mu = self.mu_net(obs)
        std = torch.exp(self.log_std)
        return Normal(mu, std)

    def _log_prob_from_distribution(self, pi, act):
        return pi.log_prob(act).sum(axis=-1)    # Last axis sum needed for Torch Normal distribution


class MLPCritic(nn.Module):

    def __init__(self, obs_dim, hidden_sizes, activation):
        super().__init__()
        self.v_net = mlp([obs_dim] + list(hidden_sizes) + [1], activation)

    def forward(self, obs):
        return torch.squeeze(self.v_net(obs), -1) # Critical to ensure v has right shape.



class MLPActorCritic(nn.Module):
    def __init__(self, observation_space, action_space,
                 hidden_sizes=(64, 64), activation=nn.Tanh):
        super().__init__()

        obs_dim = observation_space.shape[0]

        # policy builder depends on action space
        if isinstance(action_space, Box):
            self.pi = MLPGaussianActor(obs_dim, action_space.shape[0], hidden_sizes, activation)
        elif isinstance(action_space, Discrete):
            self.pi = MLPCategoricalActor(obs_dim, action_space.n, hidden_sizes, activation)

        # build value function
        self.v = MLPCritic(obs_dim, hidden_sizes, activation)

    def step(self, obs):
        with torch.no_grad():
            pi = self.pi._distribution(obs)
            a = pi.sample()
            logp_a = self.pi._log_prob_from_distribution(pi, a)
            v = self.v(obs)
        return a.numpy(), v.numpy(), logp_a.numpy()

    def act(self, obs):
        return self.step(obs)[0]

# %%
# load the models trials, emranyat
#import random
#np.random.seed(42)
#random.seed(42)
#torch.manual_seed(42)
#torch.cuda.manual_seed(42)
#torch.backends.cudnn.deterministic = True
#torch.backends.cudnn.benchmark = False
#torch.use_deterministic_algorithms(True)
# Load the model PPO
loaded_ppo = MLPActorCritic(observation_space,action_space, hidden_sizes=(512, 512))
loaded_ppo.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_ppo_20_epochs_20k_steps_trial.pth'))
#loaded_ppo.load_state_dict(torch.load('//content/agent_ppo_100_epochs_20k_steps.pth'))

loaded_ppo.eval()  # Set the model to evaluation mode

# Load the model
loaded_ppo_llm_v2 = MLPActorCritic(observation_space_llm_v2,action_space_llm_v2, hidden_sizes=(512, 512))
loaded_ppo_llm_v2.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_ppo_llm01_al05_20_epochs_20k_steps_trial_v2_v1.pth'))

loaded_ppo_llm_v2.eval()  # Set the model to evaluation mode

# Load the model alpha 0.25 NOT DONE
loaded_ppo_llm_al025 = MLPActorCritic(observation_space_llm_v2,action_space_llm_v2, hidden_sizes=(512, 512))
loaded_ppo_llm_al025.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_ppo_llm01_al025_20_epochs_20k_steps_trial_v1.pth'))

loaded_ppo_llm_al025.eval()  # Set the model to evaluation mode

# Load the model alpha 0.75
loaded_ppo_llm_al075 = MLPActorCritic(observation_space_llm_v2,action_space_llm_v2, hidden_sizes=(512, 512))
loaded_ppo_llm_al075.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_ppo_llm01_al075_20_epochs_20k_steps_trial_v1'))

loaded_ppo_llm_al075.eval()  # Set the model to evaluation mode


# Load the model PPO Noconf
loaded_ppo_llm_noconf = MLPActorCritic(observation_space_llm,action_space_llm, hidden_sizes=(512, 512))
loaded_ppo_llm_noconf.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_ppo_llm01_Noconf_20_epochs_20k_steps_trial_v1.pth'))

loaded_ppo_llm_noconf.eval()  # Set the model to evaluation mode

# Load the model PPO benstaf 20 epochs
loaded_ppo_llm_ben20 = MLPActorCritic(observation_space_llm,action_space_llm, hidden_sizes=(512, 512))
loaded_ppo_llm_ben20.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/bensatf_files/agent_ppo_deepseek_20_epochs_20k_steps.pth'))

loaded_ppo_llm_ben20.eval()  # Set the model to evaluation mode

# Load the model PPO benstaf 100 epochs
loaded_ppo_llm_ben100 = MLPActorCritic(observation_space_llm,action_space_llm, hidden_sizes=(512, 512))
loaded_ppo_llm_ben100.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/bensatf_files/agent_ppo_deepseek_100_epochs_20k_steps_01.pth'))

loaded_ppo_llm_ben100.eval()  # Set the model to evaluation mode

# PPO and ent
# Load the model
loaded_ppo_ent1 = MLPActorCritic(observation_space_llm_v2,action_space_llm_v2, hidden_sizes=(512, 512))
loaded_ppo_ent1.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_ppo_ent1_20_epochs_20k_steps_trial_v1.pth'))

loaded_ppo_ent1.eval()  # Set the model to evaluation mode

# Load the model
loaded_ppo_ent05 = MLPActorCritic(observation_space_llm_v2,action_space_llm_v2, hidden_sizes=(512, 512))
loaded_ppo_ent05.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_ppo_ent1_20_epochs_20k_steps_trial.pth'))

loaded_ppo_ent05.eval()  # Set the model to evaluation mode

# Load the model
loaded_ppo_ent10 = MLPActorCritic(observation_space_llm_v2,action_space_llm_v2, hidden_sizes=(512, 512))
loaded_ppo_ent10.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_ppo_ent1_20_epochs_20k_steps_trial.pth'))

loaded_ppo_ent10.eval()  # Set the model to evaluation mode

# Load the model
loaded_ppo_ent = MLPActorCritic(observation_space_llm_v2,action_space_llm_v2, hidden_sizes=(512, 512))
loaded_ppo_ent.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_ppo_ent_20_epochs_20k_steps_trial_v1.pth'))

loaded_ppo_ent.eval()  # Set the model to evaluation mode

# Load the model
loaded_ppo_llm_al075_ent10 = MLPActorCritic(observation_space_llm_v2,action_space_llm_v2, hidden_sizes=(512, 512))
loaded_ppo_llm_al075_ent10.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_ppo_llm01_al075_ent10_20_epochs_20k_steps_trial.pth'))

loaded_ppo_llm_al075_ent10.eval()  # Set the model to evaluation mode



# Load the model
loaded_cppo_llm_risk = MLPActorCritic(observation_space_llm_risk,action_space_llm_risk, hidden_sizes=(512, 512))
loaded_cppo_llm_risk.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_DeepSeek_20_epochs_20k_steps_trial.pth'))

loaded_cppo_llm_risk.eval()  # Set the model to evaluation mode

# Load the model
loaded_cppo_llm_riskv1 = MLPActorCritic(observation_space_llm_risk,action_space_llm_risk, hidden_sizes=(512, 512))
loaded_cppo_llm_riskv1.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_DeepSeek_20_epochs_20k_steps_trial_v1.pth'))

loaded_cppo_llm_riskv1.eval()  # Set the model to evaluation mode


# Load the model
loaded_cppo_llm_risk_al05_be05 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_al05_be05.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_deepseek_20_epochs_20k_steps_trial_v2.pth'))

loaded_cppo_llm_risk_al05_be05.eval()  # Set the model to evaluation mode

# Load the model
loaded_cppo_llm_risk_al05_be075 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_al05_be075.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm10_al05_be075_20_epochs_20k_steps.pth'))

loaded_cppo_llm_risk_al05_be075.eval()  # Set the model to evaluation mode

# Load the model
loaded_cppo_llm_risk_be025 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_be025.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm10_be025_20_epochs_20k_steps.pth'))

loaded_cppo_llm_risk_be025.eval()  # Set the model to evaluation mode

# Load the model
loaded_cppo_llm_risk_al025_be025 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_al025_be025.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm10_al025_be025_20_epochs_20k_steps.pth'))

loaded_cppo_llm_risk_al025_be025.eval()  # Set the model to evaluation mode

# Load the model
loaded_cppo_llm_risk_al025_be05 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_al025_be05.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm10_al025_be05_20_epochs_20k_steps.pth'))

loaded_cppo_llm_risk_al025_be05.eval()  # Set the model to evaluation mode

# Load the model
loaded_cppo_llm_risk_al025_be075 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_al025_be075.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm10_al025_be075_20_epochs_20k_steps.pth'))

loaded_cppo_llm_risk_al025_be075.eval()  # Set the model to evaluation mode

# Load the model
loaded_cppo_llm_risk_al075_be025 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_al075_be025.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm10_al075_be025_20_epochs_20k_steps.pth'))

loaded_cppo_llm_risk_al075_be025.eval()  # Set the model to evaluation mode

# Load the model
loaded_cppo_llm_risk_al075_be05 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_al075_be05.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm10_al075_be05_20_epochs_20k_steps_trial_v1.pth'))

loaded_cppo_llm_risk_al075_be05.eval()  # Set the model to evaluation mode

# Load the model
loaded_cppo_llm_risk_al075_be075 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_al075_be075.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm10_al075_be075_20_epochs_20k_steps.pth'))

loaded_cppo_llm_risk_al075_be075.eval()  # Set the model to evaluation mode


# Load the model
loaded_cppo_llm_risk_01_10_al05_be075 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_01_10_al05_be075.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm_01-10_al05_be075_20_epochs_20k_steps_trial.pth'))

loaded_cppo_llm_risk_01_10_al05_be075.eval()  # Set the model to evaluation mode

# Load the model risk_v2_0
loaded_cppo_llm_risk_v2_0 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_v2_0.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm10_20_epochs_20k_steps_trial.pth'))

loaded_cppo_llm_risk_v2_0.eval()  # Set the model to evaluation mode


# Load the model risk_ben
loaded_cppo_llm_risk_ben = MLPActorCritic(observation_space_llm_risk,action_space_llm_risk, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_ben.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_deepseek_100_epochs_20k_steps.pth'))

loaded_cppo_llm_risk_ben.eval()  # Set the model to evaluation mode

# Load the model risk_Noconf
loaded_cppo_llm_risk_noconf = MLPActorCritic(observation_space_llm_risk,action_space_llm_risk, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_noconf.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/Files/agent_cppo_llm10_Noconf_20_epochs_20k_steps_trial_me.pth'))

loaded_cppo_llm_risk_noconf.eval()  # Set the model to evaluation mode

# Load the model risk_Noconf Qi
loaded_cppo_llm_risk_noconfqi = MLPActorCritic(observation_space_llm_risk,action_space_llm_risk, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_noconfqi.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/trained_models/agent_cppo_llm10_Noconf_100_epochs_20k_steps_trail.pth'))

loaded_cppo_llm_risk_noconfqi.eval()  # Set the model to evaluation mode

# CPPO and ent
# Load the model
device = torch.device('cpu')
loaded_cppo_ent1 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_ent1.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/trained_models/agent_cppo_ent1_20_epochs_20k_steps_trail_gpu_new.pth', map_location=device))

loaded_cppo_ent1.eval()  # Set the model to evaluation mode

# Load the model NOT DONE 
device = torch.device('cpu')
loaded_cppo_ent = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_ent.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/trained_models/agent_cppo_llm10_ent_20_epochs_20k_steps_trial_gpu_v2.pth', map_location=device))

loaded_cppo_ent.eval()  # Set the model to evaluation mode


# Load the model
device = torch.device('cpu')
loaded_cppo_llm_risk_ent1 = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_ent1.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/trained_models/agent_cppo_llm10_ent1_20_epochs_20k_steps_trail_gpu.pth', map_location=device))

loaded_cppo_llm_risk_ent1.eval()  # Set the model to evaluation mode

# Load the model
device = torch.device('cpu')
loaded_cppo_llm_risk_ent = MLPActorCritic(observation_space_llm_risk_v2,action_space_llm_risk_v2, hidden_sizes=(512, 512))
loaded_cppo_llm_risk_ent.load_state_dict(torch.load('C:/Users/lenovo-pc/Documents/GitHub/FinRL_DeepSeek/trained_models/agent_cppo_llm10_ent_20_epochs_20k_steps_trial_gpu_v2.pth', map_location=device))

loaded_cppo_llm_risk_ent.eval()  # Set the model to evaluation mode
# Out:
# MLPActorCritic(
#   (pi): MLPGaussianActor(
#     (mu_net): Sequential(
#       (0): Linear(in_features=1177, out_features=512, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): Tanh()
#       (4): Linear(in_features=512, out_features=84, bias=True)
#       (5): Identity()
#     )
#   )
#   (v): MLPCritic(
#     (v_net): Sequential(
#       (0): Linear(in_features=1177, out_features=512, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): Tanh()
#       (4): Linear(in_features=512, out_features=1, bias=True)
#       (5): Identity()
#     )
#   )
# )

# %%
def DRL_prediction(act, environment):
    import torch
    _torch = torch

    state, _ = environment.reset()
    account_memory = []  # To store portfolio values
    actions_memory = []  # To store actions taken
    portfolio_distribution = []  # To store portfolio distribution
    episode_total_assets = [environment.initial_amount]

    with _torch.no_grad():
        for i in range(len(environment.df.index.unique())):
            s_tensor = _torch.as_tensor((state,), dtype=torch.float32, device=torch.device("cuda" if torch.cuda.is_available() else "cpu"))
            a_tensor, _, _ = act.step(s_tensor)  # Compute action
            action = a_tensor[0]  # Extract action

            # Step through the environment
            state, reward, done, _, _ = environment.step(action)

            # Get stock prices for the current day
            price_array = environment.df.loc[environment.day, "close"].values

            # Stock holdings and cash balance
            stock_holdings = environment.num_stock_shares
            cash_balance = environment.asset_memory[-1]

            # Calculate total portfolio value
            total_asset = cash_balance + (price_array * stock_holdings).sum()

            # Calculate portfolio distribution
            stock_values = price_array * stock_holdings
            total_invested = stock_values.sum()
            distribution = stock_values / total_asset  # Fraction of each stock in the total portfolio
            cash_fraction = cash_balance / total_asset

            # Store results
            episode_total_assets.append(total_asset)
            account_memory.append(total_asset)
            actions_memory.append(action)
            portfolio_distribution.append({"cash": cash_fraction, "stocks": distribution.tolist()})

       #     print("Total Asset Value:", total_asset)
        #    print("Portfolio Distribution:", {"cash": cash_fraction, "stocks": distribution.tolist()})

            if done:
                break

    print("Test Finished!")
    return episode_total_assets, account_memory, actions_memory, portfolio_distribution

# %%
# predictions of trial, emranyat
import copy
# PPO
environment_copy = copy.deepcopy(e_trade_gym)
act_copy = copy.deepcopy(loaded_ppo)
df_assets_ppo, df_account_value_ppo, df_actions_ppo, df_portfolio_distribution_ppo = DRL_prediction(act=act_copy, environment=environment_copy)

# Prediction for PPO-DeepSeek 0.1%
df_assets_ppo_llm_v2, df_account_value_ppo_llm_v2, df_actions_ppo_llm_v2, df_portfolio_distribution_ppo_llm_v2 = DRL_prediction(
    act=loaded_ppo_llm_v2, environment=e_trade_ppo_gym_01_al05
)
# Prediction for PPO-DeepSeek 0.1% and alpha 0.25
df_assets_ppo_llm_al025, df_account_value_ppo_llm_al025, df_actions_ppo_llm_al025, df_portfolio_distribution_ppo_llm_al025 = DRL_prediction(
    act=loaded_ppo_llm_al025, environment=e_trade_ppo_gym_01_al025 
)
# Prediction for PPO-DeepSeek 0.1% and alpha 0.75
df_assets_ppo_llm_al075, df_account_value_ppo_llm_al075, df_actions_ppo_llm_al075, df_portfolio_distribution_ppo_llm_al075 = DRL_prediction(
    act=loaded_ppo_llm_al075, environment=e_trade_ppo_gym_01_al075 
)
# Prediction for PPO-DeepSeek Noconf
df_assets_ppo_llm_noconf, df_account_value_ppo_llm_noconf, df_actions_ppo_llm_noconf, df_portfolio_distribution_ppo_llm_noconf = DRL_prediction(
    act=loaded_ppo_llm_noconf, environment=e_trade_ppo_gym_Noconf 
)
# Prediction for PPO-DeepSeek ben20 epochs
df_assets_ppo_llm_ben20, df_account_value_ppo_llm_ben20, df_actions_ppo_llm_ben20, df_portfolio_distribution_ppo_llm_ben20 = DRL_prediction(
    act=loaded_ppo_llm_ben20, environment=e_trade_llm_gym
)
# Prediction for PPO-DeepSeek ben100 epochs
df_assets_ppo_llm_ben100, df_account_value_ppo_llm_ben100, df_actions_ppo_llm_ben100, df_portfolio_distribution_ppo_llm_ben100 = DRL_prediction(
    act=loaded_ppo_llm_ben100, environment=e_trade_llm_gym
)

# Prediction for PPO-DeepSeek ent1
df_assets_ppo_ent1, df_account_value_ppo_ent1, df_actions_ppo_ent1, df_portfolio_distribution_ppo_ent1 = DRL_prediction(
    act=loaded_ppo_ent1, environment=e_trade_ppo_gym_ent  
)

# Prediction for PPO-DeepSeek ent05
df_assets_ppo_ent05, df_account_value_ppo_ent05, df_actions_ppo_ent05, df_portfolio_distribution_ppo_ent05 = DRL_prediction(
    act=loaded_ppo_ent05, environment=e_trade_ppo_gym_ent 
)

# Prediction for PPO-DeepSeek ent10
df_assets_ppo_ent10, df_account_value_ppo_ent10, df_actions_ppo_ent10, df_portfolio_distribution_ppo_ent10 = DRL_prediction(
    act=loaded_ppo_ent10, environment=e_trade_ppo_gym_ent 
)

# Prediction for PPO-DeepSeek ent
df_assets_ppo_ent, df_account_value_ppo_ent, df_actions_ppo_ent, df_portfolio_distribution_ppo_ent = DRL_prediction(
    act=loaded_ppo_ent, environment=e_trade_ppo_gym_ent 
)
# Prediction for PPO-DeepSeek 0.1% and alpha 0.75
df_assets_ppo_llm_al075_ent10, df_account_value_ppo_llm_al075_ent10, df_actions_ppo_llm_al075_ent10, df_portfolio_distribution_ppo_llm_al075_ent10 = DRL_prediction(
    act=loaded_ppo_llm_al075_ent10, environment=e_trade_ppo_gym_01_al075 
)


# CPPO
# Prediction for CPPO-DeepSeek 10% risk
df_assets_cppo_llm_risk, df_account_value_cppo_llm_risk, df_actions_cppo_llm_risk, df_portfolio_distribution_cppo_llm_risk = DRL_prediction(
   act=loaded_cppo_llm_risk, environment=e_trade_llm_risk_gym
)
# Prediction for CPPO-DeepSeek 10% risk v1
df_assets_cppo_llm_riskv1, df_account_value_cppo_llm_riskv1, df_actions_cppo_llm_riskv1, df_portfolio_distribution_cppo_llm_riskv1 = DRL_prediction(
   act=loaded_cppo_llm_riskv1, environment=e_trade_llm_risk_gym
)
# Prediction for CPPO-DeepSeek 10% risk v2
df_assets_cppo_llm_risk_be025, df_account_value_cppo_llm_risk_be025, df_actions_cppo_llm_risk_be025, df_portfolio_distribution_cppo_llm_risk_be025 = DRL_prediction(
   act=loaded_cppo_llm_risk_be025, environment=e_trade_cppo_gym_10 
)
# Prediction for CPPO-DeepSeek 10% risk v2 al05 be05
df_assets_cppo_llm_risk_al05_be05, df_account_value_cppo_llm_risk_al05_be05, df_actions_cppo_llm_risk_al05_be05, df_portfolio_distribution_cppo_llm_risk_al05_be05 = DRL_prediction(
   act=loaded_cppo_llm_risk_al05_be05, environment=e_trade_cppo_gym_10 
)
# Prediction for CPPO-DeepSeek 10% risk v2 al05 be075
df_assets_cppo_llm_risk_al05_be075, df_account_value_cppo_llm_risk_al05_be075, df_actions_cppo_llm_risk_al05_be075, df_portfolio_distribution_cppo_llm_risk_al05_be075 = DRL_prediction(
   act=loaded_cppo_llm_risk_al05_be075, environment=e_trade_cppo_gym_10 
)
# Prediction for CPPO-DeepSeek 10% risk v2 al025 be05
df_assets_cppo_llm_risk_al025_be025, df_account_value_cppo_llm_risk_al025_be025, df_actions_cppo_llm_risk_al025_be025, df_portfolio_distribution_cppo_llm_risk_al025_be025 = DRL_prediction(
   act=loaded_cppo_llm_risk_al025_be025, environment=e_trade_cppo_gym_10_al025 
)
# Prediction for CPPO-DeepSeek 10% risk v2 al025 be05
df_assets_cppo_llm_risk_al025_be05, df_account_value_cppo_llm_risk_al025_be05, df_actions_cppo_llm_risk_al025_be05, df_portfolio_distribution_cppo_llm_risk_al025_be05 = DRL_prediction(
   act=loaded_cppo_llm_risk_al025_be05, environment=e_trade_cppo_gym_10_al025 
)
# Prediction for CPPO-DeepSeek 10% risk v2 al025 be05
df_assets_cppo_llm_risk_al025_be075, df_account_value_cppo_llm_risk_al025_be075, df_actions_cppo_llm_risk_al025_be075, df_portfolio_distribution_cppo_llm_risk_al025_be075 = DRL_prediction(
   act=loaded_cppo_llm_risk_al025_be075, environment=e_trade_cppo_gym_10_al025 
)
# Prediction for CPPO-DeepSeek 10% risk v2 al075 be05
df_assets_cppo_llm_risk_al075_be025, df_account_value_cppo_llm_risk_al075_be025, df_actions_cppo_llm_risk_al075_be025, df_portfolio_distribution_cppo_llm_risk_al075_be025 = DRL_prediction(
   act=loaded_cppo_llm_risk_al075_be025, environment=e_trade_cppo_gym_10_al075 
)
# Prediction for CPPO-DeepSeek 10% risk v2 al075 be05
df_assets_cppo_llm_risk_al075_be05, df_account_value_cppo_llm_risk_al075_be05, df_actions_cppo_llm_risk_al075_be05, df_portfolio_distribution_cppo_llm_risk_al075_be05 = DRL_prediction(
   act=loaded_cppo_llm_risk_al075_be05, environment=e_trade_cppo_gym_10_al075 
)
# Prediction for CPPO-DeepSeek 10% risk v2 al075 be075
df_assets_cppo_llm_risk_al075_be075, df_account_value_cppo_llm_risk_al075_be075, df_actions_cppo_llm_risk_al075_be075, df_portfolio_distribution_cppo_llm_risk_al075_be075 = DRL_prediction(
   act=loaded_cppo_llm_risk_al075_be075, environment=e_trade_cppo_gym_10_al075 
)
# Prediction for CPPO-DeepSeek 10% risk v2 al05 be075 and ppo-llm =01 whule cppo-llm=10
df_assets_cppo_llm_risk_01_10_al05_be075, df_account_value_cppo_llm_risk_01_10_al05_be075, df_actions_cppo_llm_risk_01_10_al05_be075, df_portfolio_distribution_cppo_llm_risk_01_10_al05_be075 = DRL_prediction(
   act=loaded_cppo_llm_risk_01_10_al05_be075, environment=e_trade_cppo_gym_01 
)
# Prediction for CPPO-DeepSeek 10% risk v2_0
df_assets_cppo_llm_risk_v2_0, df_account_value_cppo_llm_risk_v2_0, df_actions_cppo_llm_risk_v2_0, df_portfolio_distribution_cppo_llm_risk_v2_0 = DRL_prediction(
   act=loaded_cppo_llm_risk_v2_0, environment=e_trade_cppo_gym_10 
)
# Prediction for CPPO-DeepSeek 10% risk benstaf 100epochs
df_assets_cppo_llm_risk_ben, df_account_value_cppo_llm_risk_ben, df_actions_cppo_llm_risk_ben, df_portfolio_distribution_cppo_llm_risk_ben = DRL_prediction(
   act=loaded_cppo_llm_risk_ben, environment=e_trade_llm_risk_gym
)
# Prediction for CPPO-DeepSeek 10% risk Noconf
df_assets_cppo_llm_risk_noconf, df_account_value_cppo_llm_risk_noconf, df_actions_cppo_llm_risk_noconf, df_portfolio_distribution_cppo_llm_risk_noconf = DRL_prediction(
   act=loaded_cppo_llm_risk_noconf, environment=e_trade_cppo_gym_Noconf 
)
# Prediction for CPPO-DeepSeek 10% risk Noconf for Qi
df_assets_cppo_llm_risk_noconfqi, df_account_value_cppo_llm_risk_noconfqi, df_actions_cppo_llm_risk_noconfqi, df_portfolio_distribution_cppo_llm_risk_noconfqi = DRL_prediction(
   act=loaded_cppo_llm_risk_noconfqi, environment=e_trade_cppo_gym_Noconf 
)

# CPPO and ent 
# Prediction for CPPO-DeepSeek risk with ent0.1
df_assets_cppo_ent1, df_account_value_cppo_ent1, df_actions_cppo_ent1, df_portfolio_distribution_cppo_ent1 = DRL_prediction(
   act=loaded_cppo_ent1, environment=e_trade_cppo_gym_ent 
)
# Prediction for CPPO-DeepSeek risk with ent
df_assets_cppo_ent, df_account_value_cppo_ent, df_actions_cppo_ent, df_portfolio_distribution_cppo_ent = DRL_prediction(
   act=loaded_cppo_ent, environment=e_trade_cppo_gym_ent 
)

# CPPO llm and ent
# Prediction for CPPO-DeepSeek 10% risk with ent1
df_assets_cppo_llm_risk_ent1, df_account_value_cppo_llm_risk_ent1, df_actions_cppo_llm_risk_ent1, df_portfolio_distribution_cppo_llm_risk_ent1 = DRL_prediction(
   act=loaded_cppo_llm_risk_ent1, environment=e_trade_cppo_gym_10 
)
# Prediction for CPPO-DeepSeek 10% risk with ent
df_assets_cppo_llm_risk_ent, df_account_value_cppo_llm_risk_ent, df_actions_cppo_llm_risk_ent, df_portfolio_distribution_cppo_llm_risk_ent = DRL_prediction(
   act=loaded_cppo_llm_risk_ent, environment=e_trade_cppo_gym_10 
)
# Out:
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# day: 28, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1014081.74
# total_reward: 14081.74
# total_cost: 5190.83
# total_trades: 1574
# Sharpe: 0.870
# =================================
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!
# Test Finished!

# %% [markdown]
# # Part 4: NASDAQ 100 index

# %% [markdown]
# **Add** NASDAQ 100 index as a baseline to compare with.

# %%
#TRAIN_START_DATE = '2013-01-01'
#TRAIN_END_DATE = '2018-12-31'
#TRADE_START_DATE = '2019-01-01'
#TRADE_END_DATE = '2023-12-31'

TRAIN_START_DATE = '2022-01-01'
TRAIN_END_DATE = '2023-02-15'
TRADE_START_DATE = '2023-02-16'
TRADE_END_DATE = '2023-03-30'

# %%
df_dji = YahooDownloader(
    start_date=TRADE_START_DATE, end_date=TRADE_END_DATE, ticker_list=["ndx"]
).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (28, 8)

# %%
df_dji = df_dji[["date", "close"]]
fst_day = df_dji["close"][0]
dji = pd.merge(
    df_dji["date"],
    df_dji["close"].div(fst_day).mul(1000000),
    how="outer",
    left_index=True,
    right_index=True,
).set_index("date")

# %%
if "normalized_close" not in df_dji.columns:
    fst_day = df_dji["close"].iloc[0]  # Safely get the first value
    df_dji["normalized_close"] = df_dji["close"].div(fst_day).mul(1000000)

df_dji_normalized_close = list(df_dji["normalized_close"])

# %%
fst_day = df_dji["close"].iloc[0]  # Safely get the first value
df_dji_normalized_close = list(df_dji["close"].div(fst_day).mul(1000000))

# %%
import copy
dfdf = copy.deepcopy(df_dji_normalized_close)

# %%
df_dji_normalized_close == dfdf
# Out:
# True

# %% [markdown]
# <a id='4'></a>
# # Part 5: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# Now, everything is ready, we can plot the backtest result.

# %%
# reuslts, emranyat

fst_day_ppo = df_assets_ppo[1]  # Safely get the first value
df_assets_ppo_series = pd.Series(df_assets_ppo[1:])
df_ppo_normalized_close = list(df_assets_ppo_series.div(fst_day_ppo).mul(1000000))

# Normalize PPO-DeepSeek 0.1%
fst_day_ppo_llm_v2 = df_assets_ppo_llm_v2[1]  # Safely get the first value
df_assets_ppo_llm_series_v2 = pd.Series(df_assets_ppo_llm_v2[1:])
df_ppo_llm_normalized_close_v2 = list(df_assets_ppo_llm_series_v2.div(fst_day_ppo_llm_v2).mul(1000000))

# Normalize PPO-DeepSeek 0.1% and alpha 0.25
fst_day_ppo_llm_al025 = df_assets_ppo_llm_al025[1]  # Safely get the first value
df_assets_ppo_llm_series_al025 = pd.Series(df_assets_ppo_llm_al025[1:])
df_ppo_llm_normalized_close_al025 = list(df_assets_ppo_llm_series_al025.div(fst_day_ppo_llm_al025).mul(1000000))

# Normalize PPO-DeepSeek 0.1% and alpha 0.75
fst_day_ppo_llm_al075 = df_assets_ppo_llm_al075[1]  # Safely get the first value
df_assets_ppo_llm_series_al075 = pd.Series(df_assets_ppo_llm_al075[1:])
df_ppo_llm_normalized_close_al075 = list(df_assets_ppo_llm_series_al075.div(fst_day_ppo_llm_al075).mul(1000000))

# Normalize PPO-DeepSeek Noconf
fst_day_ppo_llm_noconf = df_assets_ppo_llm_noconf[1]  # Safely get the first value
df_assets_ppo_llm_series_noconf = pd.Series(df_assets_ppo_llm_noconf[1:])
df_ppo_llm_normalized_close_noconf = list(df_assets_ppo_llm_series_noconf.div(fst_day_ppo_llm_noconf).mul(1000000))

# Normalize PPO-DeepSeek Noconf
fst_day_ppo_llm_ben20 = df_assets_ppo_llm_ben20[1]  # Safely get the first value
df_assets_ppo_llm_series_ben20 = pd.Series(df_assets_ppo_llm_ben20[1:])
df_ppo_llm_normalized_close_ben20 = list(df_assets_ppo_llm_series_ben20.div(fst_day_ppo_llm_ben20).mul(1000000))

# Normalize PPO-DeepSeek Noconf
fst_day_ppo_llm_ben100 = df_assets_ppo_llm_ben100[1]  # Safely get the first value
df_assets_ppo_llm_series_ben100 = pd.Series(df_assets_ppo_llm_ben100[1:])
df_ppo_llm_normalized_close_ben100 = list(df_assets_ppo_llm_series_ben100.div(fst_day_ppo_llm_ben100).mul(1000000))

# Normalize PPO ent1
fst_day_ppo_ent1 = df_assets_ppo_ent1[1]  # Safely get the first value
df_assets_ppo_series_ent1 = pd.Series(df_assets_ppo_ent1[1:])
df_ppo_normalized_close_ent1 = list(df_assets_ppo_series_ent1.div(fst_day_ppo_ent1).mul(1000000))

# Normalize PPO ent05
fst_day_ppo_ent05 = df_assets_ppo_ent05[1]  # Safely get the first value
df_assets_ppo_series_ent05 = pd.Series(df_assets_ppo_ent05[1:])
df_ppo_normalized_close_ent05 = list(df_assets_ppo_series_ent05.div(fst_day_ppo_ent05).mul(1000000))

# Normalize PPO ent10
fst_day_ppo_ent10 = df_assets_ppo_ent10[1]  # Safely get the first value
df_assets_ppo_series_ent10 = pd.Series(df_assets_ppo_ent10[1:])
df_ppo_normalized_close_ent10 = list(df_assets_ppo_series_ent10.div(fst_day_ppo_ent10).mul(1000000))

# Normalize PPO ent
fst_day_ppo_ent = df_assets_ppo_ent[1]  # Safely get the first value
df_assets_ppo_series_ent = pd.Series(df_assets_ppo_ent[1:])
df_ppo_normalized_close_ent = list(df_assets_ppo_series_ent.div(fst_day_ppo_ent).mul(1000000))

# Normalize PPO-DeepSeek 0.1% and alpha 0.75 and ent10
fst_day_ppo_llm_al075_ent10 = df_assets_ppo_llm_al075_ent10[1]  # Safely get the first value
df_assets_ppo_llm_series_al075_ent10 = pd.Series(df_assets_ppo_llm_al075_ent10[1:])
df_ppo_llm_normalized_close_al075_ent10 = list(df_assets_ppo_llm_series_al075_ent10.div(fst_day_ppo_llm_al075_ent10).mul(1000000))


# 
fst_day_cppo_llm_risk = df_assets_cppo_llm_risk[1]  # Safely get the first value
df_assets_cppo_llm_risk_series = pd.Series(df_assets_cppo_llm_risk[1:])
df_cppo_llm_risk_normalized_close = list(df_assets_cppo_llm_risk_series.div(fst_day_cppo_llm_risk).mul(1000000))

fst_day_cppo_llm_riskv1 = df_assets_cppo_llm_riskv1[1]  # Safely get the first value
df_assets_cppo_llm_risk_seriesv1 = pd.Series(df_assets_cppo_llm_riskv1[1:])
df_cppo_llm_risk_normalized_closev1 = list(df_assets_cppo_llm_risk_seriesv1.div(fst_day_cppo_llm_riskv1).mul(1000000))

fst_day_cppo_llm_risk_be025 = df_assets_cppo_llm_risk_be025[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_be025 = pd.Series(df_assets_cppo_llm_risk_be025[1:])
df_cppo_llm_risk_normalized_close_be025 = list(df_assets_cppo_llm_risk_series_be025.div(fst_day_cppo_llm_risk_be025).mul(1000000))

fst_day_cppo_llm_risk_al05_be05 = df_assets_cppo_llm_risk_al05_be05[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_al05_be05 = pd.Series(df_assets_cppo_llm_risk_al05_be05[1:])
df_cppo_llm_risk_normalized_close_al05_be05 = list(df_assets_cppo_llm_risk_series_al05_be05.div(fst_day_cppo_llm_risk_al05_be05).mul(1000000))

fst_day_cppo_llm_risk_al05_be075 = df_assets_cppo_llm_risk_al05_be075[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_al05_be075 = pd.Series(df_assets_cppo_llm_risk_al05_be075[1:])
df_cppo_llm_risk_normalized_close_al05_be075 = list(df_assets_cppo_llm_risk_series_al05_be075.div(fst_day_cppo_llm_risk_al05_be075).mul(1000000))

fst_day_cppo_llm_risk_al025_be025 = df_assets_cppo_llm_risk_al025_be025[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_al025_be025 = pd.Series(df_assets_cppo_llm_risk_al025_be025[1:])
df_cppo_llm_risk_normalized_close_al025_be025 = list(df_assets_cppo_llm_risk_series_al025_be025.div(fst_day_cppo_llm_risk_al025_be025).mul(1000000))

fst_day_cppo_llm_risk_al025_be05 = df_assets_cppo_llm_risk_al025_be05[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_al025_be05 = pd.Series(df_assets_cppo_llm_risk_al025_be05[1:])
df_cppo_llm_risk_normalized_close_al025_be05 = list(df_assets_cppo_llm_risk_series_al025_be05.div(fst_day_cppo_llm_risk_al025_be05).mul(1000000))

fst_day_cppo_llm_risk_al025_be075 = df_assets_cppo_llm_risk_al025_be075[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_al025_be075 = pd.Series(df_assets_cppo_llm_risk_al025_be075[1:])
df_cppo_llm_risk_normalized_close_al025_be075 = list(df_assets_cppo_llm_risk_series_al025_be075.div(fst_day_cppo_llm_risk_al025_be075).mul(1000000))

fst_day_cppo_llm_risk_al075_be025 = df_assets_cppo_llm_risk_al075_be025[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_al075_be025 = pd.Series(df_assets_cppo_llm_risk_al075_be025[1:])
df_cppo_llm_risk_normalized_close_al075_be025 = list(df_assets_cppo_llm_risk_series_al075_be025.div(fst_day_cppo_llm_risk_al075_be025).mul(1000000))

fst_day_cppo_llm_risk_al075_be05 = df_assets_cppo_llm_risk_al075_be05[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_al075_be05 = pd.Series(df_assets_cppo_llm_risk_al075_be05[1:])
df_cppo_llm_risk_normalized_close_al075_be05 = list(df_assets_cppo_llm_risk_series_al075_be05.div(fst_day_cppo_llm_risk_al075_be05).mul(1000000))

fst_day_cppo_llm_risk_al075_be075 = df_assets_cppo_llm_risk_al075_be075[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_al075_be075 = pd.Series(df_assets_cppo_llm_risk_al075_be075[1:])
df_cppo_llm_risk_normalized_close_al075_be075 = list(df_assets_cppo_llm_risk_series_al075_be075.div(fst_day_cppo_llm_risk_al075_be075).mul(1000000))

fst_day_cppo_llm_risk_01_10_al05_be075 = df_assets_cppo_llm_risk_01_10_al05_be075[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_01_10_al05_be075 = pd.Series(df_assets_cppo_llm_risk_01_10_al05_be075[1:])
df_cppo_llm_risk_normalized_close_01_10_al05_be075 = list(df_assets_cppo_llm_risk_series_01_10_al05_be075.div(fst_day_cppo_llm_risk_01_10_al05_be075).mul(1000000))

fst_day_cppo_llm_risk_v2_0 = df_assets_cppo_llm_risk_v2_0[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_v2_0 = pd.Series(df_assets_cppo_llm_risk_v2_0[1:])
df_cppo_llm_risk_normalized_close_v2_0 = list(df_assets_cppo_llm_risk_series_v2_0.div(fst_day_cppo_llm_risk_v2_0).mul(1000000))

fst_day_cppo_llm_risk_ben = df_assets_cppo_llm_risk_ben[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_ben = pd.Series(df_assets_cppo_llm_risk_ben[1:])
df_cppo_llm_risk_normalized_close_ben = list(df_assets_cppo_llm_risk_series_ben.div(fst_day_cppo_llm_risk_ben).mul(1000000))

fst_day_cppo_llm_risk_noconf = df_assets_cppo_llm_risk_noconf[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_noconf = pd.Series(df_assets_cppo_llm_risk_noconf[1:])
df_cppo_llm_risk_normalized_close_noconf = list(df_assets_cppo_llm_risk_series_noconf.div(fst_day_cppo_llm_risk_noconf).mul(1000000))

fst_day_cppo_llm_risk_noconfqi = df_assets_cppo_llm_risk_noconfqi[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_noconfqi = pd.Series(df_assets_cppo_llm_risk_noconfqi[1:])
df_cppo_llm_risk_normalized_close_noconfqi = list(df_assets_cppo_llm_risk_series_noconfqi.div(fst_day_cppo_llm_risk_noconfqi).mul(1000000))


# CPPO and ent 1
fst_day_cppo_ent1 = df_assets_cppo_ent1[1]  # Safely get the first value
df_assets_cppo_series_ent1 = pd.Series(df_assets_cppo_ent1[1:])
df_cppo_normalized_close_ent1 = list(df_assets_cppo_series_ent1.div(fst_day_cppo_ent1).mul(1000000))

# ent
fst_day_cppo_ent = df_assets_cppo_ent[1]  # Safely get the first value
df_assets_cppo_series_ent = pd.Series(df_assets_cppo_ent[1:])
df_cppo_normalized_close_ent = list(df_assets_cppo_series_ent.div(fst_day_cppo_ent).mul(1000000))


# CPPO LLM ent 1
fst_day_cppo_llm_risk_ent1 = df_assets_cppo_llm_risk_ent1[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_ent1 = pd.Series(df_assets_cppo_llm_risk_ent1[1:])
df_cppo_llm_risk_normalized_close_ent1 = list(df_assets_cppo_llm_risk_series_ent1.div(fst_day_cppo_llm_risk_ent1).mul(1000000))

# ent
fst_day_cppo_llm_risk_ent = df_assets_cppo_llm_risk_ent[1]  # Safely get the first value
df_assets_cppo_llm_risk_series_ent = pd.Series(df_assets_cppo_llm_risk_ent[1:])
df_cppo_llm_risk_normalized_close_ent = list(df_assets_cppo_llm_risk_series_ent.div(fst_day_cppo_llm_risk_ent).mul(1000000))

# %%
def filter_to_common_dates(trade, df_dji, df_assets_ppo, df_dji_normalized_close):
    """
    Filters df_assets_ppo and df_dji_normalized_close based on the common dates from trade and df_dji.

    Parameters:
        trade (pd.DataFrame): DataFrame containing a 'date' column for the trade data.
        df_dji (pd.DataFrame): DataFrame containing a 'date' column for DJI data.
        df_assets_ppo (list or array-like): Values corresponding to trade['date'].
        df_dji_normalized_close (list or array-like): Values corresponding to df_dji['date'].

    Returns:
        pd.Series, pd.Series: Filtered series for df_assets_ppo and df_dji_normalized_close.
    """
    # Extract unique trading dates from trade and DJI dates
    trade_dates = pd.to_datetime(trade['date'].unique())
    dji_dates = pd.to_datetime(df_dji['date'].unique())


  #  first_date = trade_dates[0]
   # date_before_first = first_date - pd.DateOffset(days=1)

# Prepend the date before the first date to trade_dates
    #trade_dates = pd.DatetimeIndex([date_before_first] + trade_dates.tolist())

    # Convert inputs to pandas Series with their respective dates as indices
    df_assets_ppo_series = pd.Series(df_assets_ppo, index=trade_dates)
    df_dji_normalized_close_series = pd.Series(df_dji_normalized_close, index=dji_dates)

    # Find the common dates
    common_dates = trade_dates.intersection(dji_dates)

    # Filter both series to the common dates
    df_assets_ppo_filtered = df_assets_ppo_series.reindex(common_dates)
    df_dji_normalized_close_filtered = df_dji_normalized_close_series.reindex(common_dates)

    # Return the filtered series
    return df_assets_ppo_filtered, df_dji_normalized_close_filtered, common_dates

# %%
#common_dates

# %%
# filter the results, emranyat
df_assets_ppo_filtered, df_dji_normalized_close_filtered, common_dates = filter_to_common_dates(trade, df_dji, df_ppo_normalized_close, df_dji_normalized_close)

df_assets_ppo_llm_filtered_v2, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_llm_normalized_close_v2, df_dji_normalized_close)
df_assets_ppo_llm_filtered_al025, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_llm_normalized_close_al025, df_dji_normalized_close)
df_assets_ppo_llm_filtered_al075, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_llm_normalized_close_al075, df_dji_normalized_close)

df_assets_ppo_llm_filtered_noconf, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_llm_normalized_close_noconf, df_dji_normalized_close)
df_assets_ppo_llm_filtered_ben20, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_llm_normalized_close_ben20, df_dji_normalized_close)
df_assets_ppo_llm_filtered_ben100, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_llm_normalized_close_ben100, df_dji_normalized_close)
df_assets_ppo_filtered_ent1, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_normalized_close_ent1, df_dji_normalized_close)
df_assets_ppo_filtered_ent05, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_normalized_close_ent05, df_dji_normalized_close)
df_assets_ppo_filtered_ent10, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_normalized_close_ent10, df_dji_normalized_close)
df_assets_ppo_filtered_ent, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_normalized_close_ent, df_dji_normalized_close)
df_assets_ppo_llm_filtered_al075_ent10, _, _ = filter_to_common_dates(trade, df_dji, df_ppo_llm_normalized_close_al075_ent10, df_dji_normalized_close)


df_assets_cppo_llm_risk_filtered, df_dji_normalized_close_filtered, common_dates = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close, df_dji_normalized_close)
df_assets_cppo_llm_risk_filteredv1, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_closev1, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_be025, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_be025, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_al05_be05, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_al05_be05, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_al05_be075, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_al05_be075, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_al025_be025, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_al025_be025, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_al025_be05, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_al025_be05, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_al025_be075, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_al025_be075, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_al075_be025, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_al075_be025, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_al075_be05, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_al075_be05, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_al075_be075, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_al075_be075, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_01_10_al05_be075, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_01_10_al05_be075, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_v2_0, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_v2_0, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_ben, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_ben, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_noconf, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_noconf, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_noconfqi, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_noconfqi, df_dji_normalized_close)

# ent1 cppo
df_assets_cppo_filtered_ent1, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_normalized_close_ent1, df_dji_normalized_close)
df_assets_cppo_filtered_ent, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_normalized_close_ent, df_dji_normalized_close)

# ent1 cppo with LLM
df_assets_cppo_llm_risk_filtered_ent1, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_ent1, df_dji_normalized_close)
df_assets_cppo_llm_risk_filtered_ent, _, _ = filter_to_common_dates(trade, df_dji, df_cppo_llm_risk_normalized_close_ent, df_dji_normalized_close)

# %%
result = pd.DataFrame(
    {
        "PPO 20 epochs": df_assets_ppo_filtered,
        #"CPPO 100 epochs": df_assets_cppo_filtered,
        "PPO-LLM-al.5 20 epochs": df_assets_ppo_llm_filtered_v2,
        "PPO-LLM-al.25 20 epochs": df_assets_ppo_llm_filtered_al025,
        "PPO-LLM-al.75 20 epochs": df_assets_ppo_llm_filtered_al075,
        "PPO-LLM-Noconf 20 epochs": df_assets_ppo_llm_filtered_noconf,
        "PPO-LLM-old 20 epochs": df_assets_ppo_llm_filtered_ben20,
        "PPO-LLM-old 100 epochs": df_assets_ppo_llm_filtered_ben100,
        "PPO-ent1 20 epochs": df_assets_ppo_filtered_ent1,
        "PPO-ent05 20 epochs": df_assets_ppo_filtered_ent05,
        "PPO-ent10 20 epochs": df_assets_ppo_filtered_ent10,
        "PPO-ent 20 epochs": df_assets_ppo_filtered_ent,
        "PPO-LLM-al.75-ent10 20 epochs": df_assets_ppo_llm_filtered_al075_ent10,

    #    "PPO-Llama 100 epochs": df_assets_ppo_llama_filtered,
        "CPPO-LLM 20 epochs": df_assets_cppo_llm_risk_filtered,
        "CPPO-LLM-v1 20 epochs": df_assets_cppo_llm_risk_filteredv1,
        "CPPO-LLM-al.5-be.25 20 epochs": df_assets_cppo_llm_risk_filtered_be025,
        "CPPO-LLM-al.5-be.5 20 epochs": df_assets_cppo_llm_risk_filtered_al05_be05,
        "CPPO-LLM-al.5-be.75 20 epochs": df_assets_cppo_llm_risk_filtered_al05_be075,
        "CPPO-LLM-al.25-be.25 20 epochs": df_assets_cppo_llm_risk_filtered_al025_be025,
        "CPPO-LLM-al.25-be.5 20 epochs": df_assets_cppo_llm_risk_filtered_al025_be05,
        "CPPO-LLM-al.25-be.75 20 epochs": df_assets_cppo_llm_risk_filtered_al025_be075,
        "CPPO-LLM-al.75-be.25 20 epochs": df_assets_cppo_llm_risk_filtered_al075_be025,
        "CPPO-LLM-al.75-be.5 20 epochs": df_assets_cppo_llm_risk_filtered_al075_be05,
        "CPPO-LLM-al.75-be.75 20 epochs": df_assets_cppo_llm_risk_filtered_al075_be075,
        "CPPO-LLM-01-10-al.5-be.75 20 epochs": df_assets_cppo_llm_risk_filtered_01_10_al05_be075,
        "CPPO-LLM-v2-0 20 epochs": df_assets_cppo_llm_risk_filtered_v2_0,

        "CPPO-LLM-old 100 epochs": df_assets_cppo_llm_risk_filtered_ben,
        "CPPO-LLM-Noconf 20 epochs": df_assets_cppo_llm_risk_filtered_noconf,
        "CPPO-LLM-Noconf-Qi 20 epochs": df_assets_cppo_llm_risk_filtered_noconfqi,

        "CPPO-ent1 20 epochs": df_assets_cppo_filtered_ent1,
        "CPPO-ent 20 epochs": df_assets_cppo_filtered_ent,

        "CPPO-LLM-ent1 20 epochs": df_assets_cppo_llm_risk_filtered_ent1,
        "CPPO-LLM-ent 20 epochs": df_assets_cppo_llm_risk_filtered_ent,


        "Nasdaq-100 index": df_dji_normalized_close_filtered,
    }
)

# Display the result
print(result)
# Out:
#             PPO 20 epochs  PPO-LLM-al.5 20 epochs  PPO-LLM-al.25 20 epochs  \
# 2023-02-16   1.000000e+06            1.000000e+06             1.000000e+06
# 2023-02-17   9.853475e+05            9.859162e+05             9.894218e+05
# 2023-02-21   9.849107e+05            9.870182e+05             9.893460e+05
# 2023-02-22   9.904460e+05            9.921548e+05             9.941190e+05
# 2023-02-23   9.772973e+05            9.863815e+05             9.924078e+05
# 2023-02-24   9.866657e+05            1.005884e+06             1.007794e+06
# 2023-02-27   9.883816e+05            1.004642e+06             1.008033e+06
# 2023-02-28   9.879832e+05            1.008768e+06             1.013810e+06
# 2023-03-01   9.936137e+05            1.015735e+06             1.019343e+06
# 2023-03-02   1.013114e+06            1.030043e+06             1.034474e+06
# 2023-03-03   1.025607e+06            1.035035e+06             1.033027e+06
# 2023-03-06   1.014392e+06            1.022239e+06             1.019136e+06
# 2023-03-07   1.007109e+06            1.017441e+06             1.012865e+06
# 2023-03-08   9.918699e+05            1.001008e+06             9.954441e+05
# 2023-03-09   9.717085e+05            9.872240e+05             9.848836e+05
# 2023-03-13   9.944243e+05            1.005617e+06             9.970371e+05
# 2023-03-14   9.788192e+05            9.987114e+05             9.862716e+05
# 2023-03-15   9.773279e+05            1.002284e+06             9.970584e+05
# 2023-03-16   9.331885e+05            9.768400e+05             9.905820e+05
# 2023-03-17   9.597647e+05            9.956289e+05             1.001746e+06
# 2023-03-17            9.899875e+05      1.006221e+06
# 2023-03-20            9.988767e+05      1.009655e+06
# 2023-03-21            9.762701e+05      1.024027e+06
# 2023-03-22            9.927369e+05      1.010020e+06
# 2023-03-23            9.931214e+05      1.023046e+06
# 2023-03-24            9.891415e+05      1.026086e+06
# 2023-03-27            9.885960e+05      1.018532e+06
# 2023-03-28            1.004583e+06      1.013509e+06
# 2023-03-29            1.004583e+06      1.032433e+06
#
# [28 rows x 32 columns]

# %%
import copy
#results0425 = copy.deepcopy(result)
results0425_v1 = copy.deepcopy(result)
results0425.shape
# Out:
# (28, 32)

# %%
result.iloc[1,1],  results0425.iloc[1,1]
# Out:
# (985358.8294542165, 985841.9934599608)

# %%
results0425 == results0425_v1
# Out:
#             PPO 20 epochs  PPO-LLM-al.5 20 epochs  PPO-LLM-al.25 20 epochs  \
# 2023-02-16           True                    True                     True
# 2023-02-17          False                   False                    False
# 2023-02-21          False                   False                    False
# 2023-02-22          False                   False                    False
# 2023-02-23          False                   False                    False
# 2023-02-24          False                   False                    False
# 2023-02-27          False                   False                    False
# 2023-02-28          False                   False                    False
# 2023-03-01          False                   False                    False
# 2023-03-02          False                   False                    False
# 2023-03-03          False                   False                    False
# 2023-03-06          False                   False                    False
# 2023-03-07          False                   False                    False
# 2023-03-08          False                   False                    False
# 2023-03-09          False                   False                    False
# 2023-03-13          False                   False                    False
# 2023-03-14          False                   False                    False
# 2023-03-15          False                   False                    False
# 2023-03-16          False                   False                    False
# 2023-03-17          False                   False                    False
# 2023-03-20          False                   False                    False
# 2023-03-21          False                   False                    False
# 2023-03-22          False                   False                    False
# 2023-03-23          False                   False                    False
# 2023-03-24          False                   False                    False
# 2023-03-27          False                   False                    False
# 2023-03-28          False                   False                    False
# 2023-03-29          False                   False                    False
#
#             PPO-LLM-al.75 20 epochs  PPO-LLM-Noconf 20 epochs  \
# 2023-02-16                     True                      True
# 2023-02-17                    False                     False
# 2023-02-21                    False                     False
# 2023-02-22                    False                     False
# 2023-02-23                    False                     False
# 2023-02-24                    False                     False
# 2023-02-27                    False                     False
# 2023-02-28                    False                     False
# 2023-03-01                    False                     False
# 2023-03-02                    False                     False
# 2023-03-03                    False                     False
# 2023-03-06                    False                     False
# 2023-03-07                    False                     False
# 2023-03-08                    False                     False
# 2023-03-09                    False                     False
# 2023-03-13                    False                     False
# 2023-03-14                    False                     False
# 2023-03-15                    False                     False
# 2023-03-16                    False                     False
# 2023-03-17                    False                     False
# 2023-03-20                    False                     False
# 2023-03-21                    False                     False
# 2023-03-22                    False                     False
# 2023-03-23                    False                     False
# 2023-03-24                    False                     False
# 2023-03-27                    False                     False
# 2023-03-28                    False                     False
# 2023-03-29                    False                     False
#
#             PPO-LLM-old 20 epochs  PPO-LLM-old 100 epochs  PPO-ent1 20 epochs  \
# 2023-02-16                   True                    True                True
# 2023-02-17                  False                   False               False
# 2023-02-21                  False                   False               False
# 2023-02-22                  False                   False               False
# 2023-02-23                  False                   False               False
# 2023-02-24                  False                   False               False
columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Utility Functions
def calculate_metric(returns_strategy, returns_benchmark, confidence_level=0.05, upside_confidence=0.95):
    """Calculate performance metrics: IR, CVaR, and Rachev Ratio."""
    excess_return = returns_strategy - returns_benchmark
    ir = excess_return.mean() / excess_return.std()
    var = np.percentile(returns_strategy, confidence_level * 100)
    cvar = returns_strategy[returns_strategy <= var].mean()
    upside_var = np.percentile(returns_strategy, upside_confidence * 100)
    downside_var = var
    rachev_ratio = returns_strategy[returns_strategy >= upside_var].mean() / abs(returns_strategy[returns_strategy <= downside_var].mean())
    # Downturn Outperformance
    benchmark_downturns = returns_benchmark < 0
    downturn_outperformance = (returns_strategy[benchmark_downturns] > returns_benchmark[benchmark_downturns]).sum() / benchmark_downturns.sum()
   
    return {"Information Ratio": ir, 
            #"CVaR": cvar, 
            "Cumulative Return": (1 + returns_strategy).prod() - 1, 
            "Rachev Ratio": rachev_ratio, 
            "Max Drawdown": (1 + returns_strategy).cumprod().min() - 1, 
            "Outperformance Frequency": (np.sum(returns_strategy > returns_benchmark) / len(returns_strategy)) * 100, 
            "Downturn Outperformance": downturn_outperformance *100 }

def align_returns(result, col_strategy, col_benchmark):
    """Align returns for strategy and benchmark."""
    returns_strategy = result[col_strategy].pct_change().dropna()
    print(result)
    returns_benchmark = result[col_benchmark].pct_change().dropna()
    return returns_strategy.align(returns_benchmark, join="inner")

# Metrics Calculation
def compute_metrics(result, strategies, benchmark, confidence_level=0.05, upside_confidence=0.95):
    """
    Compute metrics for multiple strategies compared to a benchmark.

    Parameters:
        result (pd.DataFrame): DataFrame with strategies and benchmark columns.
        strategies (list): List of strategy column names.
        benchmark (str): Benchmark column name.
        confidence_level (float): Confidence level for CVaR calculation.
        upside_confidence (float): Confidence level for upside in Rachev Ratio.

    Returns:
        dict: Performance metrics for each strategy.
    """
    metrics = {}
    for strategy in strategies:
        aligned_strategy, aligned_benchmark = align_returns(result, strategy, benchmark)
        metrics[strategy] = calculate_metric(
            aligned_strategy, aligned_benchmark, confidence_level, upside_confidence
        )
        #print(aligned_strategy, aligned_benchmark)
    return metrics

# Plotting
def plot_cumulative_returns(result, metrics, strategies, benchmark):
    """
    Plot cumulative returns for strategies and benchmark with annotated metrics.

    Parameters:
        result (pd.DataFrame): DataFrame with strategies and benchmark.
        metrics (dict): Performance metrics.
        strategies (list): List of strategy column names.
        benchmark (str): Benchmark column name.
    """
    plt.figure(figsize=(12, 6))
    for strategy in strategies:
        cumulative_returns = (1 + result[strategy].pct_change().dropna()).cumprod()
        plt.plot(cumulative_returns, label=f"{strategy}")
    cumulative_benchmark = (1 + result[benchmark].pct_change().dropna()).cumprod()
    plt.plot(cumulative_benchmark, label=f"{benchmark} (Benchmark)")
    plt.title("Cumulative Returns with Performance Metrics")
    plt.legend()
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

# Example Usage
# Assuming `result` DataFrame is prepared with "PPO 25 epochs", "CPPO 25 epochs", and "Nasdaq-100 index"
strategies = [
"PPO 20 epochs",
#"CPPO 100 epochs",
"PPO-LLM-al.5 20 epochs",
"PPO-LLM-al.25 20 epochs",
"PPO-LLM-al.75 20 epochs",
"PPO-LLM-Noconf 20 epochs",
"PPO-ent1 20 epochs",
"PPO-ent05 20 epochs",
"PPO-ent10 20 epochs",
"PPO-ent 20 epochs",
"PPO-LLM-al.75-ent10 20 epochs",
#"PPO-LLM-old 20 epochs",
"PPO-LLM-old 100 epochs",
#"PPO-Llama 100 epochs",
#"CPPO-LLM 20 epochs",
#"CPPO-LLM-v1 20 epochs",
#"CPPO-LLM-v2 20 epochs",
#"CPPO-LLM-v2-0 20 epochs",
#"CPPO-LLM-old 100 epochs",
#"CPPO-LLM-Noconf 20 epochs",
#"CPPO-LLM-Noconf-Qi 20 epochs",
#"CPPO-LLM-ent1 20 epochs"
#"CPPO-Llama 100 epochs",
]
#strategies = ["PPO 20 epochs", "CPPO 20 epochs", "CPPO-DeepSeek 20 epochs"]
benchmark = "Nasdaq-100 index"
metrics = compute_metrics(result, strategies, benchmark)
plot_cumulative_returns(result, metrics, strategies, benchmark)

# Print metrics
for strategy, strategy_metrics in metrics.items():
    print(f"{strategy} Metrics:")
    for metric_name, value in strategy_metrics.items():
        print(f"  {metric_name}: {value:.4f}")
# Out:
#             PPO 20 epochs  PPO-LLM-al.5 20 epochs  PPO-LLM-al.25 20 epochs  \
# 2023-02-16   1.000000e+06            1.000000e+06             1.000000e+06
# 2023-02-17   9.854360e+05            9.822307e+05             9.889928e+05
# 2023-02-21   9.837791e+05            9.846779e+05             9.886076e+05
# 2023-02-22   9.878295e+05            9.911574e+05             9.930042e+05
# 2023-02-23   9.742489e+05            9.801514e+05             9.923449e+05
# 2023-02-24   9.817140e+05            9.946033e+05             1.006996e+06
# 2023-02-27   9.786966e+05            9.896484e+05             1.006938e+06
# 2023-02-28   9.792494e+05            9.906006e+05             1.010462e+06
# 2023-03-01   9.838071e+05            9.968594e+05             1.016875e+06
# 2023-03-02   9.987619e+05            1.010320e+06             1.032883e+06
# 2023-03-03   1.007104e+06            1.013307e+06             1.029068e+06
# 2023-03-06   9.948319e+05            9.994236e+05             1.015450e+06
# 2023-03-07   9.891358e+05            9.944406e+05             1.013173e+06
# 2023-03-08   9.768466e+05            9.784836e+05             9.956348e+05
# 2023-03-09   9.609375e+05            9.621379e+05             9.842969e+05
# 2023-03-13   9.784773e+05            9.802223e+05             9.960600e+05
# 2023-03-14   9.638459e+05            9.740171e+05             9.867320e+05
# 2023-03-15   9.678276e+05            9.846952e+05             9.990253e+05
# 2023-03-16   9.285769e+05            9.639353e+05             9.887516e+05
# 2023-03-17   9.503640e+05            9.760834e+05             1.001936e+06
# 2023-03-20   9.905961e+05            1.000551e+06             1.027406e+06
# 2023-03-21   9.654351e+05            9.816932e+05             1.015169e+06
# 2023-03-22   9.751948e+05            9.992766e+05             1.036919e+06
# 2023-03-23   9.557238e+05            9.999476e+05             1.039177e+06
# 2023-03-24   9.554591e+05            9.956320e+05             1.037383e+06
# 2023-03-27   9.463496e+05            9.952326e+05             1.040390e+06
# 2023-03-28   9.861843e+05            1.016700e+06             1.074951e+06
# 2023-03-29   9.861843e+05            1.016700e+06             1.074951e+06
#
#             PPO-LLM-al.75 20 epochs  PPO-LLM-Noconf 20 epochs  \
# 2023-02-16             1.000000e+
#   Outperformance Frequency: 55.5556
#   Downturn Outperformance: 91.6667
# PPO-LLM-al.25 20 epochs Metrics:
#   Information Ratio: 0.0723
#   Cumulative Return: 0.0750
#   Rachev Ratio: 1.9199
#   Max Drawdown: -0.0157
#   Outperformance Frequency: 55.5556
#   Downturn Outperformance: 91.6667
# PPO-LLM-al.75 20 epochs Metrics:
#   Information Ratio: -0.0133
#   Cumulative Return: 0.0254
#   Rachev Ratio: 1.2145
#   Max Drawdown: -0.0289
#   Outperformance Frequency: 55.5556
#   Downturn Outperformance: 91.6667
# PPO-LLM-Noconf 20 epochs Metrics:
#   Information Ratio: -0.0014
#   Cumulative Return: 0.0324
#   Rachev Ratio: 1.4204
#   Max Drawdown: -0.0293
#   Outperformance Frequency: 48.1481
#   Downturn Outperformance: 83.3333
# PPO-ent1 20 epochs Metrics:
#   Information Ratio: 0.0187
#   Cumulative Return: 0.0434
#   Rachev Ratio: 1.0826
#   Max Drawdown: -0.0288
#   Outperformance Frequency: 55.5556
#   Downturn Outperformance: 91.6667
# PPO-ent05 20 epochs Metrics:
#   Information Ratio: 0.0357
#   Cumulative Return: 0.0526
#   Rachev Ratio: 1.8131
#   Max Drawdown: -0.0163
#   Outperformance Frequency: 51.8519
#   Downturn Outperformance: 91.6667
# PPO-ent10 20 epochs Metrics:
#   Information Ratio: 0.0773
#   Cumulative Return: 0.0802
#   Rachev Ratio: 1.8602
#   Max Drawdown: -0.0196
#   Outperformance Frequency: 51.8519
#   Downturn Outperformance: 83.3333
# PPO-ent 20 epochs Metrics:
#   Information Ratio: -0.0397
#   Cumulative Return: 0.0073
#   Rachev Ratio: 1.3477
#   Max Drawdown: -0.0638
#   Outperformance Frequency: 51.8519
#   Downturn Outperformance: 83.3333
# PPO-LLM-al.75-ent10 20 epochs Metrics:
#   Information Ratio: -0.0077
#   Cumulative Return: 0.0271
#   Rachev Ratio: 1.4944
#   Max Drawdown: -0.0329
#   Outperformance Frequency: 55.5556
#   Downturn Outperformance: 91.6667
# PPO-LLM-old 100 epochs Metrics:
#   Information Ratio: -0.1014
#   Cumulative Return: -0.0262
#   Rachev Ratio: 0.9699
#   Max Drawdown: -0.0905
#   Outperformance Frequency: 48.1481
#   Downturn Outperformance: 75.0000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Utility Functions
def calculate_metric(returns_strategy, returns_benchmark, confidence_level=0.05, upside_confidence=0.95):
    """Calculate performance metrics: IR, CVaR, and Rachev Ratio."""
    excess_return = returns_strategy - returns_benchmark
    ir = excess_return.mean() / excess_return.std()
    var = np.percentile(returns_strategy, confidence_level * 100)
    cvar = returns_strategy[returns_strategy <= var].mean()
    upside_var = np.percentile(returns_strategy, upside_confidence * 100)
    downside_var = var
    rachev_ratio = returns_strategy[returns_strategy >= upside_var].mean() / abs(returns_strategy[returns_strategy <= downside_var].mean())
    # Downturn Outperformance
    benchmark_downturns = returns_benchmark < 0
    downturn_outperformance = (returns_strategy[benchmark_downturns] > returns_benchmark[benchmark_downturns]).sum() / benchmark_downturns.sum()
   
    return {"Information Ratio": ir, 
            #"CVaR": cvar, 
            "Cumulative Return": (1 + returns_strategy).prod() - 1, 
            "Rachev Ratio": rachev_ratio, 
            "Max Drawdown": (1 + returns_strategy).cumprod().min() - 1, 
            "Outperformance Frequency": (np.sum(returns_strategy > returns_benchmark) / len(returns_strategy)) * 100, 
            "Downturn Outperformance": downturn_outperformance *100 }

def align_returns(result, col_strategy, col_benchmark):
    """Align returns for strategy and benchmark."""
    returns_strategy = result[col_strategy].pct_change().dropna()
    print(result)
    returns_benchmark = result[col_benchmark].pct_change().dropna()
    return returns_strategy.align(returns_benchmark, join="inner")

# Metrics Calculation
def compute_metrics(result, strategies, benchmark, confidence_level=0.05, upside_confidence=0.95):
    """
    Compute metrics for multiple strategies compared to a benchmark.

    Parameters:
        result (pd.DataFrame): DataFrame with strategies and benchmark columns.
        strategies (list): List of strategy column names.
        benchmark (str): Benchmark column name.
        confidence_level (float): Confidence level for CVaR calculation.
        upside_confidence (float): Confidence level for upside in Rachev Ratio.

    Returns:
        dict: Performance metrics for each strategy.
    """
    metrics = {}
    for strategy in strategies:
        aligned_strategy, aligned_benchmark = align_returns(result, strategy, benchmark)
        metrics[strategy] = calculate_metric(
            aligned_strategy, aligned_benchmark, confidence_level, upside_confidence
        )
        #print(aligned_strategy, aligned_benchmark)
    return metrics

# Plotting
def plot_cumulative_returns(result, metrics, strategies, benchmark):
    """
    Plot cumulative returns for strategies and benchmark with annotated metrics.

    Parameters:
        result (pd.DataFrame): DataFrame with strategies and benchmark.
        metrics (dict): Performance metrics.
        strategies (list): List of strategy column names.
        benchmark (str): Benchmark column name.
    """
    plt.figure(figsize=(12, 6))
    for strategy in strategies:
        cumulative_returns = (1 + result[strategy].pct_change().dropna()).cumprod()
        plt.plot(cumulative_returns, label=f"{strategy}")
    cumulative_benchmark = (1 + result[benchmark].pct_change().dropna()).cumprod()
    plt.plot(cumulative_benchmark, label=f"{benchmark} (Benchmark)")
    plt.title("Cumulative Returns with Performance Metrics")
    plt.legend()
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

# Example Usage
# Assuming `result` DataFrame is prepared with "PPO 25 epochs", "CPPO 25 epochs", and "Nasdaq-100 index"
strategies = [
#"PPO 20 epochs",
#"CPPO 100 epochs",
#"PPO-LLM 20 epochs",
#"PPO-LLM-Noconf 20 epochs",
#"PPO-LLM-old 20 epochs",
#"PPO-LLM-old 100 epochs",
#"PPO-Llama 100 epochs",
#"CPPO-LLM 20 epochs",
#"CPPO-LLM-v1 20 epochs",
##"CPPO-LLM-be.5 20 epochs",
"CPPO-LLM-al.25-be.25 20 epochs",
"CPPO-LLM-al.25-be.5 20 epochs",
"CPPO-LLM-al.25-be.75 20 epochs",
"CPPO-LLM-al.5-be.25 20 epochs",
"CPPO-LLM-al.5-be.5 20 epochs",
"CPPO-LLM-al.5-be.75 20 epochs",
"CPPO-LLM-al.75-be.25 20 epochs",
"CPPO-LLM-al.75-be.5 20 epochs",
"CPPO-LLM-al.75-be.75 20 epochs",
"CPPO-LLM-01-10-al.5-be.75 20 epochs",
"CPPO-LLM-v2-0 20 epochs",
"CPPO-LLM-old 100 epochs",
"CPPO-LLM-Noconf 20 epochs",
#"CPPO-LLM-Noconf-Qi 20 epochs",
"CPPO-ent1 20 epochs",
"CPPO-ent 20 epochs",
"CPPO-LLM-ent1 20 epochs",
#"CPPO-LLM-ent 20 epochs"
]
#strategies = ["PPO 20 epochs", "CPPO 20 epochs", "CPPO-DeepSeek 20 epochs"]
benchmark = "Nasdaq-100 index"
metrics = compute_metrics(result, strategies, benchmark)
plot_cumulative_returns(result, metrics, strategies, benchmark)

# Print metrics
for strategy, strategy_metrics in metrics.items():
    print(f"{strategy} Metrics:")
    for metric_name, value in strategy_metrics.items():
        print(f"  {metric_name}: {value:.4f}")
# Out:
#             PPO 20 epochs  PPO-LLM-al.5 20 epochs  PPO-LLM-al.25 20 epochs  \
# 2023-02-16   1.000000e+06            1.000000e+06             1.000000e+06
# 2023-02-17   9.854360e+05            9.822307e+05             9.889928e+05
# 2023-02-21   9.837791e+05            9.846779e+05             9.886076e+05
# 2023-02-22   9.878295e+05            9.911574e+05             9.930042e+05
# 2023-02-23   9.742489e+05            9.801514e+05             9.923449e+05
# 2023-02-24   9.817140e+05            9.946033e+05             1.006996e+06
# 2023-02-27   9.786966e+05            9.896484e+05             1.006938e+06
# 2023-02-28   9.792494e+05            9.906006e+05             1.010462e+06
# 2023-03-01   9.838071e+05            9.968594e+05             1.016875e+06
# 2023-03-02   9.987619e+05            1.010320e+06             1.032883e+06
# 2023-03-03   1.007104e+06            1.013307e+06             1.029068e+06
# 2023-03-06   9.948319e+05            9.994236e+05             1.015450e+06
# 2023-03-07   9.891358e+05            9.944406e+05             1.013173e+06
# 2023-03-08   9.768466e+05            9.784836e+05             9.956348e+05
# 2023-03-09   9.609375e+05            9.621379e+05             9.842969e+05
# 2023-03-13   9.784773e+05            9.802223e+05             9.960600e+05
# 2023-03-14   9.638459e+05            9.740171e+05             9.867320e+05
# 2023-03-15   9.678276e+05            9.846952e+05             9.990253e+05
# 2023-03-16   9.285769e+05            9.639353e+05             9.887516e+05
# 2023-03-17   9.503640e+05            9.760834e+05             1.001936e+06
# 2023-03-20   9.905961e+05            1.000551e+06             1.027406e+06
# 2023-03-21   9.654351e+05            9.816932e+05             1.015169e+06
# 2023-03-22   9.751948e+05            9.992766e+05             1.036919e+06
# 2023-03-23   9.557238e+05            9.999476e+05             1.039177e+06
# 2023-03-24   9.554591e+05            9.956320e+05             1.037383e+06
# 2023-03-27   9.463496e+05            9.952326e+05             1.040390e+06
# 2023-03-28   9.861843e+05            1.016700e+06             1.074951e+06
# 2023-03-29   9.861843e+05            1.016700e+06             1.074951e+06
#
#             PPO-LLM-al.75 20 epochs  PPO-LLM-Noconf 20 epochs  \
# 2023-02-16             1.000000e+06              1.000000e+06
# 2023-02-17             9.862634e+05              9.838582e+05
# 2023-02-21             9.855869e+05              9.818959e+05
# 2023-02-22             9.884196e+05              9.932290e+05
# 2023-02-23             9.828031e+05              9.875367e+05
# 2023-02-24             1.001004e+06              9.944377e+05
# 2023-02-27             9.991960e+05              9.920069e+05
# 2023-02-28             1.001078e+06              9.972585e+05
# 2023-03-01             1.008327e+06              1.001949e+06
#   Outperformance Frequency: 55.5556
#   Downturn Outperformance: 91.6667
# CPPO-LLM-al.5-be.5 20 epochs Metrics:
#   Information Ratio: -0.0872
#   Cumulative Return: -0.0117
#   Rachev Ratio: 0.8267
#   Max Drawdown: -0.0607
#   Outperformance Frequency: 44.4444
#   Downturn Outperformance: 83.3333
# CPPO-LLM-al.5-be.75 20 epochs Metrics:
#   Information Ratio: 0.0358
#   Cumulative Return: 0.0530
#   Rachev Ratio: 1.3484
#   Max Drawdown: -0.0275
#   Outperformance Frequency: 51.8519
#   Downturn Outperformance: 83.3333
# CPPO-LLM-al.75-be.25 20 epochs Metrics:
#   Information Ratio: -0.0251
#   Cumulative Return: 0.0205
#   Rachev Ratio: 1.0429
#   Max Drawdown: -0.0472
#   Outperformance Frequency: 51.8519
#   Downturn Outperformance: 83.3333
# CPPO-LLM-al.75-be.5 20 epochs Metrics:
#   Information Ratio: -0.0157
#   Cumulative Return: 0.0252
#   Rachev Ratio: 1.2070
#   Max Drawdown: -0.0370
#   Outperformance Frequency: 51.8519
#   Downturn Outperformance: 83.3333
# CPPO-LLM-al.75-be.75 20 epochs Metrics:
#   Information Ratio: -0.0237
#   Cumulative Return: 0.0207
#   Rachev Ratio: 1.0639
#   Max Drawdown: -0.0370
#   Outperformance Frequency: 51.8519
#   Downturn Outperformance: 83.3333
# CPPO-LLM-01-10-al.5-be.75 20 epochs Metrics:
#   Information Ratio: -0.0836
#   Cumulative Return: -0.0118
#   Rachev Ratio: 1.2451
#   Max Drawdown: -0.0604
#   Outperformance Frequency: 51.8519
#   Downturn Outperformance: 83.3333
# CPPO-LLM-v2-0 20 epochs Metrics:
#   Information Ratio: -0.0902
#   Cumulative Return: -0.0122
#   Rachev Ratio: 0.7969
#   Max Drawdown: -0.0537
#   Outperformance Frequency: 48.1481
#   Downturn Outperformance: 83.3333
# CPPO-LLM-old 100 epochs Metrics:
#   Information Ratio: -0.0431
#   Cumulative Return: 0.0055
#   Rachev Ratio: 1.0154
#   Max Drawdown: -0.0374
#   Outperformance Frequency: 55.5556
#   Downturn Outperformance: 83.3333
# CPPO-LLM-Noconf 20 epochs Metrics:
#   Information Ratio: -0.0075
#   Cumulative Return: 0.0271
#   Rachev Ratio: 1.2973
#   Max Drawdown: -0.0371
#   Outperformance Frequency: 55.5556
#   Downturn Outperformance: 91.6667
# CPPO-ent1 20 epochs Metrics:
#   Information Ratio: -0.0229
#   Cumulative Return: 0.0209
#   Rachev Ratio: 1.3080
#   Max Drawdown: -0.0368
#   Outperformance Frequency: 51.8519
#   Downturn Outperformance: 83.3333
# CPPO-ent 20 epochs Metrics:
#   Information Ratio: -0.0378
#   Cumulative Return: 0.0138
#   Rachev Ratio: 1.0991
#   Max Drawdown: -0.0444
#   Outperformance Frequency: 55.5556
#   Downturn Outperformance: 91.6667
# CPPO-LLM-ent1 20 epochs Metrics:
#   Information Ratio: -0.0455
#   Cumulative Return: 0.0082
#   Rachev Ratio: 1.0531
#   Max Drawdown: -0.0364
#   Outperformance Frequency: 55.5556
#   Downturn Outperformance: 91.6667

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def calculate_information_ratio(returns_strategy, returns_benchmark):
    """Calculate the Information Ratio (IR)."""
    excess_return = returns_strategy - returns_benchmark
    return excess_return.mean() / excess_return.std()

def calculate_cvar(returns_strategy, confidence_level=0.05):
    """Calculate the Conditional Value at Risk (CVaR)."""
    var = np.percentile(returns_strategy, confidence_level * 100)
    return returns_strategy[returns_strategy <= var].mean()

def calculate_rachev_ratio(returns_strategy, upside_confidence=0.95, downside_confidence=0.05):
    """Calculate the Rachev Ratio."""
    upside_var = np.percentile(returns_strategy, upside_confidence * 100)
    downside_var = np.percentile(returns_strategy, downside_confidence * 100)
    upside_mean = returns_strategy[returns_strategy >= upside_var].mean()
    downside_mean = abs(returns_strategy[returns_strategy <= downside_var].mean())
    return upside_mean / downside_mean

def align_and_compute_metrics(result, confidence_level=0.05, upside_confidence=0.95):
    """
    Align data for PPO, CPPO, and benchmark, and compute performance metrics.

    Parameters:
        result (pd.DataFrame): DataFrame with strategies and benchmark.
        confidence_level (float): Confidence level for CVaR calculation.
        upside_confidence (float): Confidence level for upside in Rachev Ratio.

    Returns:
        dict: Performance metrics for PPO and CPPO.
    """
    # Calculate returns
    returns_ppo = result["PPO 25 epochs"].pct_change().dropna()
    returns_cppo = result["CPPO 25 epochs"].pct_change().dropna()
    returns_benchmark = result["Nasdaq-100 index"].pct_change().dropna()

    # Align returns
    returns_ppo, returns_benchmark_ppo = returns_ppo.align(returns_benchmark, join="inner")
    returns_cppo, returns_benchmark_cppo = returns_cppo.align(returns_benchmark, join="inner")

    # Compute metrics
    metrics = {
        "PPO": {
            "Information Ratio": calculate_information_ratio(returns_ppo, returns_benchmark_ppo),
            "CVaR": calculate_cvar(returns_ppo, confidence_level),
            "Rachev Ratio": calculate_rachev_ratio(returns_ppo, upside_confidence, confidence_level),
        },
        "CPPO": {
            "Information Ratio": calculate_information_ratio(returns_cppo, returns_benchmark_cppo),
            "CVaR": calculate_cvar(returns_cppo, confidence_level),
            "Rachev Ratio": calculate_rachev_ratio(returns_cppo, upside_confidence, confidence_level),
        }
    }
    return metrics

def plot_cumulative_returns(result, metrics):
    """
    Plot cumulative returns for PPO, CPPO, and benchmark with annotated metrics.

    Parameters:
        result (pd.DataFrame): DataFrame with strategies and benchmark.
        metrics (dict): Performance metrics.
    """
    # Calculate cumulative returns
    cumulative_ppo = (1 + result["PPO 25 epochs"].pct_change().dropna()).cumprod()
    cumulative_cppo = (1 + result["CPPO 25 epochs"].pct_change().dropna()).cumprod()
    cumulative_benchmark = (1 + result["Nasdaq-100 index"].pct_change().dropna()).cumprod()

    # Plot
    plt.figure(figsize=(12, 6))
    plt.plot(cumulative_ppo, label=f"PPO 25 epochs (IR={metrics['PPO']['Information Ratio']:.4f})")
    plt.plot(cumulative_cppo, label=f"CPPO 25 epochs (IR={metrics['CPPO']['Information Ratio']:.4f})")
    plt.plot(cumulative_benchmark, label="Nasdaq-100 index (Benchmark)")
    plt.title("Cumulative Returns with Performance Metrics")
    plt.legend()
    plt.xlabel("Date")
    plt.ylabel("Cumulative Return")
    plt.grid()
    plt.show()

# Example Usage
# Assuming `result` DataFrame is prepared with "PPO 25 epochs", "CPPO 25 epochs", and "Nasdaq-100 index"
metrics = align_and_compute_metrics(result)
plot_cumulative_returns(result, metrics)

# Print metrics
for strategy, strategy_metrics in metrics.items():
    print(f"{strategy} Metrics:")
    for metric_name, value in strategy_metrics.items():
        print(f"  {metric_name}: {value:.4f}")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# ... (your existing code to load data and calculate strategies) ...

# Get unique trading dates from your trade data
trade_dates = pd.to_datetime(trade['date'].unique())

first_date = trade_dates[0]
date_before_first = first_date - pd.DateOffset(days=1)

# Prepend the date before the first date to trade_dates
trade_dates = pd.DatetimeIndex([date_before_first] + trade_dates.tolist())


# Reindex your strategy results to match the trading dates
df_assets_ppo_series = pd.Series(df_assets_ppo, index=trade_dates)
#df_dji_normalized_close_series = pd.Series(df_dji_normalized_close, index=trade_dates) # Convert to Series


# 1. Get dates from df_dji (Yahoo Finance data)

dji_dates = pd.to_datetime(df_dji['date'])

# 2. Find the intersection of trade_dates and dji_dates
common_dates = trade_dates.intersection(dji_dates)

# 3. Reindex df_assets_ppo to keep only common_dates
df_assets_ppo_series = pd.Series(df_assets_ppo, index=trade_dates).reindex(common_dates)

# Reindex df_dji to match common_dates, forward-filling missing values (if any)
df_dji_normalized_close_series = pd.Series(df_dji_normalized_close, index=common_dates)

# Create the DataFrame with trading dates as the index
result = pd.DataFrame(
    {
        "PPO 70 epochs": df_assets_ppo_series,
        "Nasdaq-100 index": df_dji_normalized_close_series,
    }
)

# %%
result.to_csv('result_ppo_qwen_25_epochs_20k_steps.csv')

# %%
# prompt: plot also the sharpe ratio and sortino ratio of nasdaq and ppo

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Assuming 'result' DataFrame is already created as in your provided code

# Calculate daily returns
result['PPO 70 epochs_daily_return'] = result['PPO 70 epochs'].pct_change()
result['Nasdaq-100 index_daily_return'] = result['Nasdaq-100 index'].pct_change()


# Calculate Sharpe Ratio
sharpe_ppo = np.sqrt(252) * (result['PPO 70 epochs_daily_return'].mean() / result['PPO 70 epochs_daily_return'].std())
sharpe_nasdaq = np.sqrt(252) * (result['Nasdaq-100 index_daily_return'].mean() / result['Nasdaq-100 index_daily_return'].std())

# Calculate Sortino Ratio (assuming a target return of 0)
downside_returns_ppo = result['PPO 70 epochs_daily_return'].where(result['PPO 70 epochs_daily_return'] < 0, 0)
downside_returns_nasdaq = result['Nasdaq-100 index_daily_return'].where(result['Nasdaq-100 index_daily_return'] < 0, 0)

sortino_ppo = np.sqrt(252) * (result['PPO 70 epochs_daily_return'].mean() / downside_returns_ppo.std())
sortino_nasdaq = np.sqrt(252) * (result['Nasdaq-100 index_daily_return'].mean() / downside_returns_nasdaq.std())


#Plotting
plt.figure(figsize=(12, 6))
plt.plot(result.index, result['PPO 70 epochs'], label='PPO 70 epochs')
plt.plot(result.index, result['Nasdaq-100 index'], label='Nasdaq-100 index')
plt.title('Portfolio Value Comparison')
plt.xlabel('Date')
plt.ylabel('Portfolio Value')
plt.legend()
plt.grid(True)


# Move legend to upper left
plt.legend(loc='upper left')


plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Assuming `df_assets_ppo_series` and `df_dji_normalized_close_series` are already created
returns_strategy = df_assets_ppo_series.pct_change().dropna()
returns_benchmark = df_dji_normalized_close_series.pct_change().dropna()

# Align data
returns_strategy, returns_benchmark = returns_strategy.align(returns_benchmark, join="inner")

# Information Ratio
excess_return = returns_strategy - returns_benchmark
information_ratio = excess_return.mean() / excess_return.std()

# CVaR
confidence_level = 0.05
var = np.percentile(returns_strategy, confidence_level * 100)
cvar = returns_strategy[returns_strategy <= var].mean()

# Rachev Ratio
upside_confidence = 0.95
downside_confidence = 0.05
upside_var = np.percentile(returns_strategy, upside_confidence * 100)
downside_var = np.percentile(returns_strategy, downside_confidence * 100)
rachev_ratio = returns_strategy[returns_strategy >= upside_var].mean() / abs(returns_strategy[returns_strategy <= downside_var].mean())

# Print metrics
print(f"Information Ratio: {information_ratio:.4f}")
print(f"CVaR (5%): {cvar:.4f}")
print(f"Rachev Ratio: {rachev_ratio:.4f}")

# Plot
plt.figure(figsize=(12, 6))

# Strategy and benchmark cumulative returns
cumulative_strategy = (1 + returns_strategy).cumprod()
cumulative_benchmark = (1 + returns_benchmark).cumprod()

plt.plot(cumulative_strategy, label="PPO 25 epochs (Strategy)")
plt.plot(cumulative_benchmark, label="Nasdaq-100 index (Baseline)")

# Add metrics to the plot
plt.title(f"Performance Metrics:\nIR={information_ratio:.4f}, CVaR (5%)={cvar:.4f}, Rachev={rachev_ratio:.4f}")
plt.legend()
plt.xlabel("Date")
plt.ylabel("Cumulative Return")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# ... (your existing code to load data and calculate strategies) ...

# Calculate daily returns (same as before)
# ...

# Calculate Sharpe and Sortino Ratios (same as before)
# ...

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))  # 1 row, 2 columns

# --- Subplot 1: Sharpe Ratio Comparison ---
ax1.bar(['PPO 70 epochs', 'Nasdaq-100 index'], [sharpe_ppo, sharpe_nasdaq], color=['blue', 'orange'])
ax1.set_title('Sharpe Ratio Comparison')
ax1.set_ylabel('Sharpe Ratio')

# Add Sharpe ratio values as text on top of the bars
for i, v in enumerate([sharpe_ppo, sharpe_nasdaq]):
    ax1.text(i, v + 0.05, f"{v:.2f}", ha='center', va='bottom')

# --- Subplot 2: Sortino Ratio Comparison ---
ax2.bar(['PPO 70 epochs', 'Nasdaq-100 index'], [sortino_ppo, sortino_nasdaq], color=['green', 'red'])
ax2.set_title('Sortino Ratio Comparison')
ax2.set_ylabel('Sortino Ratio')

# Add Sortino ratio values as text on top of the bars
for i, v in enumerate([sortino_ppo, sortino_nasdaq]):
    ax2.text(i, v + 0.05, f"{v:.2f}", ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Plotting
plt.figure(figsize=(16, 6))
for column in result.columns:
    plt.plot(result.index, result[column], label=column)

plt.xlabel("Date")
plt.ylabel("Portfolio Value")
plt.title("Backtesting Results (Tradable Days Only)")


# Get the first and last dates from the index
first_day = result.index[0]
last_day = result.index[-1]

# Create a list of dates for ticks, including first, last, and every 15 days
tick_dates = [first_day]  # Start with the first day
current_date = first_day + pd.DateOffset(days=15)  # Add 15 days
while current_date < last_day:
    tick_dates.append(current_date)
    current_date += pd.DateOffset(days=15)
tick_dates.append(last_day)  # Add the last day


# Remove December 13th if it's in the tick_dates list
tick_dates = [d for d in tick_dates if d.strftime('%Y-%m-%d') != '2023-12-13']


# Set x-axis ticks to the calculated tick_dates
plt.xticks(tick_dates, [d.strftime('%Y-%m-%d') for d in tick_dates], rotation=45)


#plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()

# %%
plt.rcParams["figure.figsize"] = (15,5)
plt.figure()
result.plot()
